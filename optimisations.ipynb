# %% [markdown]
# # 0. Imports

# %%
import numpy as np
import awkward as ak
import pandas as pd
import uproot as up
import vector
vector.register_awkward()
from matplotlib import pyplot as plt
K = 40000000 * (2750 / 3564)
SCALE = 12
import mplhep as hep
plt.style.use(hep.style.CMS)

# %% [markdown]
# # 1. Utility functions

# %%
def getBranch(data, l1jet):
    
    # Get list of branches relating to the given jet
    print("Getting list of interesting branches")
    interestingBranches = [branch for branch in data.keys() if l1jet in branch and not f"n{l1jet}" in branch]# and not f"{l1jet}_dau0" in branch] 
    
    # Get only branches corresponding to the desired l1jet
    print("Querying the array with interesting branches")
    l1jetData = data.arrays(interestingBranches)
    
    # Get a dictionary relating default branch names to new branch names (ie without leading ak8PuppiJets_...)
    print("Splitting branch names on _ to get renamed fields")
    renamedFields = {field : field.split('_', maxsplit=1)[-1] for field in interestingBranches}

    # Create a new awkward array with the desired l1jet branches and the new branch names
    print("Returning an ak array of the relevant data with the renamed fields")
    arr = ak.Array({renamedFields[field]: l1jetData[field] for field in l1jetData.fields})
    
    array_dict = {key: arr[key] for key in arr.fields}
    quarks4mom = ak.zip(array_dict)
    quarks4mom = ak.with_name(quarks4mom, "Momentum4D")
    
    return quarks4mom

def get_rate(mask, mb_decisions):
    # leading = ak.firsts(minbias_jets)
    rate = K * ak.sum( mask ) / len(mb_decisions)
    #(leading.mass > mass_threshold) & (leading.pt > pt_threshold)
    
    if isinstance(mb_decisions, pd.core.frame.DataFrame):
        already_passed = mb_decisions.any(axis=1).values
        not_passed_mask = mask[~already_passed]
        return rate, K * ak.sum( not_passed_mask ) / len(mb_decisions)
    else:
        return rate
    
def get_sc4_separated(sc8, sc4, N=1):
    a, b = ak.unzip( ak.cartesian([sc4, sc8[:,:N]], nested=True) )
    dists_bool = a.deltaR(b) < 0.8
    return sc4[~ak.any(dists_bool, axis=-1)]

def get_efficiency(mask, sig_decisions):
    already_passed = sig_decisions.any(axis=1).values
    total_eff = ak.sum( already_passed | mask ) / len(sig_decisions)
    pure_eff = total_eff - ( ak.sum( already_passed ) / len(sig_decisions) )
    return total_eff, pure_eff

# %% [markdown]
# # 2. Load data

# %%
path_mb_decisions = "/eos/user/l/lroberts/Phase2-L1MenuTools/outputs/V49nano_AR25/rate_tables/MinBias_RateTable_V49nano_AR25_masks.parquet"
mb_decisions = pd.read_parquet(path_mb_decisions, engine="fastparquet").astype(bool)
exclude = ["L1_SinglePfJet8_230"]
triggers_to_load = list(mb_decisions.columns.difference(exclude))
mb_decisions = mb_decisions[triggers_to_load]

path_mb = "/eos/cms/store/group/dpg_trigger/comm_trigger/L1Trigger/roward/phase2/menu/ntuples/Spring24/151X_AllAR25_FindOn/v45/MinBias_TuneCP5_14TeV-pythia8/MinBias_Spring24_200PUALCA_V45_reL1wTT_151X_AllAR25_FindOn/250615_160052/hadd/output_Phase2_L1T.root"
mb = up.open(path_mb + ":Events")
mb_sc8 = getBranch(mb, "L1puppiJetSC8_")
mb_sc4 = getBranch(mb, "L1puppiJetSC4_")

mb_sc4_separated = get_sc4_separated(mb_sc8, mb_sc4, N=1)
# Out:
# Getting list of interesting branches
# Querying the array with interesting branches
# Splitting branch names on _ to get renamed fields
# Returning an ak array of the relevant data with the renamed fields
# Getting list of interesting branches
# Querying the array with interesting branches
# Splitting branch names on _ to get renamed fields
# Returning an ak array of the relevant data with the renamed fields

# %%
path_sig_decisions = "/eos/user/l/lroberts/Phase2-L1MenuTools/outputs/V49nano_AR25/rate_tables/LH_40_qq_RateTable_V49nano_AR25_masks.parquet"
sig_decisions = pd.read_parquet(path_sig_decisions, engine="fastparquet").astype(bool)
sig_decisions = sig_decisions[triggers_to_load]

path_sig = "/eos/user/l/lroberts/Phase2-L1MenuTools/signal_samples/XtoHH_MH-40_qq_PU200_signal.root"
sig = up.open(path_sig + ":Events")
sig_sc8 = getBranch(sig, "L1puppiJetSC8_")
sig_sc4 = getBranch(sig, "L1puppiJetSC4_")

sig_sc4_separated = get_sc4_separated(sig_sc8, sig_sc4, N=1)
# Out:
# Getting list of interesting branches
# Querying the array with interesting branches
# Splitting branch names on _ to get renamed fields
# Returning an ak array of the relevant data with the renamed fields
# Getting list of interesting branches
# Querying the array with interesting branches
# Splitting branch names on _ to get renamed fields
# Returning an ak array of the relevant data with the renamed fields

# %% [markdown]
# # 3. Menu seeds

# %%
def L1_SinglePFJet8(sc8, sc4, pt_threshold):
    leading = ak.firsts(sc8)
    mask = ak.ones_like(leading.pt, dtype=bool)

    mask = mask & ( leading.pt > pt_threshold )

    return mask


def L1_SinglePFJet8_Mass(sc8, sc4, pt_threshold, mass_threshold):
    leading = ak.firsts(sc8)
    mask = ak.ones_like(leading.pt, dtype=bool)

    mask = mask & ( leading.pt > pt_threshold )
    mask = mask & ( leading.mass > mass_threshold )

    return mask

# %%
def L1_DoublePFJet8_dEtaMax(sc8, sc4, pt_thresholdA, pt_thresholdB, separation = 1.6):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    mask = mask & ( abs( leading.eta - subleading.eta ) < separation )    # eta separation
    mask = mask & ( leading.pt > pt_thresholdA )
    mask = mask & ( subleading.pt > pt_thresholdB )
    
    return mask


def L1_DoublePFJet8_dEtaMax_Mass(sc8, sc4, pt_thresholdA, mass_thresholdA, pt_thresholdB, mass_thresholdB, separation = 1.6):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    mask = mask & ( abs( leading.eta - subleading.eta ) < separation )    # eta separation
    mask = mask & ( leading.pt > pt_thresholdA )
    mask = mask & ( leading.mass > mass_thresholdA )
    mask = mask & ( subleading.pt > pt_thresholdB )
    mask = mask & ( subleading.mass > mass_thresholdB )
    
    return mask

# %%
def L1_DoublePFJet8_Sum(sc8, sc4, pt_sum_threshold):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    pt_sum = leading.pt + subleading.pt
    
    mask = mask & ( pt_sum > pt_sum_threshold )
    
    return mask


def L1_DoublePFJet8_Sum_Mass(sc8, sc4, pt_sum_threshold, mass_sum_threshold):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    pt_sum = leading.pt + subleading.pt
    mass_sum = leading.mass + subleading.mass
    
    mask = mask & ( pt_sum > pt_sum_threshold )
    mask = mask & ( mass_sum > mass_sum_threshold )
    
    return mask

# %%
def L1_DoublePFJet8_Emyr(sc8, sc4, pt_thresholdA, pt_thresholdB):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    mask = mask & (leading.pt > pt_thresholdA)
    mask = mask & (subleading.pt > pt_thresholdB)
    
    return mask


def L1_DoublePFJet8_Emyr_Mass(sc8, sc4, mass_sum_threshold, pt_thresholdA, pt_thresholdB):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    mass_sum = leading.mass + subleading.mass

    mask = mask & (mass_sum > mass_sum_threshold)
    mask = mask & (leading.pt > pt_thresholdA)
    mask = mask & (subleading.pt > pt_thresholdB)
    
    return mask


def L1_DoublePFJet8_Sum_Mass_dEtaMax(sc8, sc4, mass_sum_threshold, pt_thresholdA, pt_thresholdB, separation=1.6):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    mass_sum = leading.mass + subleading.mass

    mask = mask & (mass_sum > mass_sum_threshold)
    mask = mask & (leading.pt > pt_thresholdA)
    mask = mask & (subleading.pt > pt_thresholdB)
    mask = mask & ( abs(leading.eta - subleading.eta) < separation )
    
    return mask

# %%
def L1_DoublePFJet8_Sum_EtaMax(sc8, sc4, pt_sum_threshold, separation = 1.6):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    mask = mask & ( (leading.pt + subleading.pt) > pt_sum_threshold )
    mask = mask & ( abs( leading.eta - subleading.eta ) < separation )    # eta separation
    
    return mask


def L1_DoublePFJet8_Sum_EtaMax_Mass(sc8, sc4, pt_sum_threshold, mass_sum_threshold, separation = 1.6):
    leading = ak.firsts(sc8)
    subleading = ak.firsts(sc8[:,1:])
    mask = ak.ones_like(leading.pt, dtype=bool)
    
    pt_sum = leading.pt + subleading.pt
    mass_sum = leading.mass + subleading.mass
    
    mask = mask & ( pt_sum > pt_sum_threshold )
    mask = mask & ( mass_sum > mass_sum_threshold )
    mask = mask & ( abs( leading.eta - subleading.eta ) < separation )    # eta separation
    
    return mask

# %%
def L1_SinglePFJet8_SinglePFJet4(sc8, sc4, pt_thresholdA, pt_thresholdB):
    leading_sc8 = ak.firsts(sc8)
    leading_sc4 = ak.firsts(sc4)
    mask = ak.ones_like(leading_sc8.pt, dtype=bool)

    mask = mask & ( leading_sc8.pt > pt_thresholdA )
    mask = mask & ( leading_sc4.pt > pt_thresholdB )

    return mask


def L1_SinglePFJet8_SinglePFJet4_Mass(sc8, sc4, pt_thresholdA, mass_thresholdA, pt_thresholdB):
    leading_sc8 = ak.firsts(sc8)
    leading_sc4 = ak.firsts(sc4)
    mask = ak.ones_like(leading_sc8.pt, dtype=bool)

    mask = mask & ( leading_sc8.pt > pt_thresholdA )
    mask = mask & ( leading_sc8.mass > mass_thresholdA )
    mask = mask & ( leading_sc4.pt > pt_thresholdB )

    return mask

# %%
def L1_SinglePFJet8_DoublePFJet4(sc8, sc4, pt_thresholdA, pt_thresholdB, pt_thresholdC):
    leading_sc8 = ak.firsts(sc8)
    leading_sc4 = ak.firsts(sc4)
    subleading_sc4 = ak.firsts(sc4[:,1:])
    mask = ak.ones_like(leading_sc8.pt, dtype=bool)

    mask = mask & ( leading_sc8.pt > pt_thresholdA )
    mask = mask & ( leading_sc4.pt > pt_thresholdB )
    mask = mask & ( subleading_sc4.pt > pt_thresholdC )

    return mask


def L1_SinglePFJet8_DoublePFJet4_Mass(sc8, sc4, pt_thresholdA, mass_thresholdA, pt_thresholdB, pt_thresholdC):
    leading_sc8 = ak.firsts(sc8)
    leading_sc4 = ak.firsts(sc4)
    subleading_sc4 = ak.firsts(sc4[:,1:])
    mask = ak.ones_like(leading_sc8.pt, dtype=bool)

    mask = mask & ( leading_sc8.pt > pt_thresholdA )
    mask = mask & ( leading_sc8.mass > mass_thresholdA )
    mask = mask & ( leading_sc4.pt > pt_thresholdB )
    mask = mask & ( subleading_sc4.pt > pt_thresholdC )
    
    return mask

# %% [markdown]
# # 4. Wide cone jet seeds analysis

# %%
def rate_eff(trigger_func, *thresholds):
    total_rate, pure_rate = get_rate( trigger_func(mb_sc8, mb_sc4_separated, *thresholds), mb_decisions )
    total_eff, pure_eff = get_efficiency( trigger_func(sig_sc8, sig_sc4_separated, *thresholds), sig_decisions )
    print(f"{trigger_func.__name__}{thresholds}:\n    Total rate = {total_rate/1000:.2f} kHz, pure rate: {pure_rate/1000:.2f} kHz\n    Total eff: {total_eff*100:.2f}%, pure eff: {pure_eff*100:.2f}%")
    return total_rate, pure_rate, total_eff, pure_eff

# %%
trigger = L1_DoublePFJet8_Sum_Mass_dEtaMax
mass_sum_threshold = 32.87
pt_thresholdA = 84.98
pt_thresholdB = 73.77
_ = rate_eff(trigger, mass_sum_threshold, pt_thresholdA, pt_thresholdB)

# %%
trigger = L1_DoublePFJet8_Emyr
pt_thresholdA = 123.3    
pt_thresholdB = 50.83    # optimised 20 gev H    
_ = rate_eff(trigger, pt_thresholdA, pt_thresholdB)

trigger = L1_DoublePFJet8_Emyr_Mass
mass_sum_threshold = 32.87
pt_thresholdA = 84.98
pt_thresholdB = 73.77
_ = rate_eff(trigger, mass_sum_threshold, pt_thresholdA, pt_thresholdB)
# Out:
# L1_DoublePFJet8_Emyr(123.3, 50.83):
#     Total rate = 80.69 kHz, pure rate: 9.82 kHz
#     Total eff: 77.30%, pure eff: 2.51%
# L1_DoublePFJet8_Emyr_Mass(32.87, 84.98, 73.77):
#     Total rate = 53.09 kHz, pure rate: 9.96 kHz
#     Total eff: 80.40%, pure eff: 5.61%

# %%
trigger = L1_SinglePFJet8
pt_threshold = 126.5    # optimised
_ = rate_eff(trigger, pt_threshold)

trigger = L1_SinglePFJet8_Mass
pt_threshold = 120.7    # optimised
mass_threshold = 17.37    # optimised
_ = rate_eff(trigger, pt_threshold, mass_threshold)
# Out:
# L1_SinglePFJet8(126.5,):
#     Total rate = 86.03 kHz, pure rate: 9.82 kHz
#     Total eff: 76.92%, pure eff: 2.13%
# L1_SinglePFJet8_Mass(120.7, 17.37):
#     Total rate = 54.58 kHz, pure rate: 9.71 kHz
#     Total eff: 77.89%, pure eff: 3.09%

# %%
# MOST EFFICIENT

trigger = L1_DoublePFJet8_dEtaMax
pt_thresholdA = 82.78    # optimised
pt_thresholdB = 74.44    # optimised
_ = rate_eff(trigger, pt_thresholdA, pt_thresholdB)

trigger = L1_DoublePFJet8_dEtaMax_Mass
pt_thresholdA = 71.96    # optimised
mass_thresholdA = 15.60    # optimised
pt_thresholdB = 60.04    # optimised
mass_thresholdB = 12.91    # optimised
_ = rate_eff(trigger, pt_thresholdA, mass_thresholdA, pt_thresholdB, mass_thresholdB)
# Out:
# L1_DoublePFJet8_dEtaMax(82.78, 74.44):
#     Total rate = 77.44 kHz, pure rate: 9.99 kHz
#     Total eff: 81.24%, pure eff: 6.45%
# L1_DoublePFJet8_dEtaMax_Mass(71.96, 15.6, 60.04, 12.91):
#     Total rate = 33.93 kHz, pure rate: 9.88 kHz
#     Total eff: 82.27%, pure eff: 7.48%

# %%
# MOST EFFICIENT MH50, MH40

trigger = L1_DoublePFJet8_Sum
pt_sum_threshold = 201.0    # optimised
_ = rate_eff(trigger, pt_sum_threshold)

trigger = L1_DoublePFJet8_Sum_Mass
pt_sum_threshold = 177.8    # optimised
mass_sum_threshold = 34.01    # optimised
_ = rate_eff(trigger, pt_sum_threshold, mass_sum_threshold)
# Out:
# L1_DoublePFJet8_Sum(201.0,):
#     Total rate = 92.54 kHz, pure rate: 9.94 kHz
#     Total eff: 78.01%, pure eff: 3.22%
# L1_DoublePFJet8_Sum_Mass(177.8, 34.01):
#     Total rate = 53.42 kHz, pure rate: 9.99 kHz
#     Total eff: 80.34%, pure eff: 5.54%

# %%
# MOST EFFICIENT AND MOST EFFICIENT FOR MH50

trigger = L1_DoublePFJet8_Sum_EtaMax
pt_sum_threshold = 180.0    # optimised
separation = 1.6
_ = rate_eff(trigger, pt_sum_threshold, separation)

trigger = L1_DoublePFJet8_Sum_EtaMax_Mass
pt_sum_threshold = 166.1
mass_sum_threshold = 30.92
separation = 1.6
_ = rate_eff(trigger, pt_sum_threshold, mass_sum_threshold, separation)
# Out:
# L1_DoublePFJet8_Sum_EtaMax(180.0, 1.6):
#     Total rate = 75.31 kHz, pure rate: 9.99 kHz
#     Total eff: 80.98%, pure eff: 6.19%
# L1_DoublePFJet8_Sum_EtaMax_Mass(166.1, 30.92, 1.6):
#     Total rate = 46.62 kHz, pure rate: 9.89 kHz
#     Total eff: 82.85%, pure eff: 8.06%

# %%
# trigger = L1_SinglePFJet8_SinglePFJet4
# pt_thresholdA = 120.8    # optimised
# pt_thresholdB = 53.02    # optimised
# _ = rate_eff(trigger, pt_thresholdA, pt_thresholdB)

# trigger = L1_SinglePFJet8_SinglePFJet4_Mass
# pt_thresholdA = 82.23    # optimised
# mass_thresholdA = 24.55    # optimised
# pt_thresholdB = 52.74    # optimised
# _ = rate_eff(trigger, pt_thresholdA, mass_thresholdA, pt_thresholdB)

# %%
# trigger = L1_SinglePFJet8_DoublePFJet4
# pt_thresholdA = 121.0    # optimised
# pt_thresholdB = 52.87    # optimised
# pt_thresholdC = 4.758    # optimised
# _ = rate_eff(trigger, pt_thresholdA, pt_thresholdB, pt_thresholdC)

# trigger = L1_SinglePFJet8_DoublePFJet4_Mass
# pt_thresholdA = 84.36    # optimised
# mass_thresholdA = 24.59    # optimised
# pt_thresholdB = 51.52    # optimised
# pt_thresholdC = 9.019    # optimised
# _ = rate_eff(trigger, pt_thresholdA, mass_thresholdA, pt_thresholdB, pt_thresholdC)

# %% [markdown]
# # 5. Optimisation

# %%
from scipy.optimize import differential_evolution as de
def objective(x, trigger):
    total_rate, pure_rate, total_eff, pure_eff = rate_eff(trigger, *x)
    if pure_rate > 10000:
        return pure_eff
    else:
        return -pure_eff

# %%
#L1_DoublePFJet8_Sum_Mass_dEtaMax
bounds = ((0, 70), (30, 160), (20, 150))
L1_DoublePFJet8_Sum_Mass_dEtaMax_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_Sum_Mass_dEtaMax,), workers=-1, disp=True)
L1_DoublePFJet8_Sum_Mass_dEtaMax_Opti
# Out:
# /eos/home-l/lroberts/Phase2-L1MenuTools/data/.env/lib64/python3.9/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(42.791638836310284), np.float64(140.3134523247012), np.float64(31.731481907481147)):
#     Total rate = 10.10 kHz, pure rate: 0.31 kHz
#     Total eff: 92.67%, pure eff: 0.86%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.025240206370754), np.float64(85.24489309583312), np.float64(130.24009159005905)):
#     Total rate = 9.69 kHz, pure rate: 0.03 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(29.960286947330633), np.float64(120.24207225891777), np.float64(140.606922047515)):
#     Total rate = 6.33 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(31.359872356929003), np.float64(128.2990532697526), np.float64(81.53178311736438)):
#     Total rate = 18.87 kHz, pure rate: 0.42 kHz
#     Total eff: 92.98%, pure eff: 1.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(15.3344800448587), np.float64(59.04255036644681), np.float64(77.27269742312457)):
#     Total rate = 65.74 kHz, pure rate: 6.94 kHz
#     Total eff: 95.14%, pure eff: 3.33%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(49.109972144664994), np.float64(65.07500123551787), np.float64(23.85664488699154)):
#     Total rate = 9.99 kHz, pure rate: 1.11 kHz
#     Total eff: 94.15%, pure eff: 2.34%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.290570604234475), np.float64(92.68015709679231), np.float64(84.41987709634823)):
#     Total rate = 33.03 kHz, pure rate: 2.02 kHz
#     Total eff: 94.27%, pure eff: 2.46%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(9.697911049016739), np.float64(56.05815205055519), np.float64(39.8541038350612)):
#     Total rate = 509.27 kHz, pure rate: 378.54 kHz
#     Total eff: 97.23%, pure eff: 5.42%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(21.268721992844597), np.float64(127.5559436862543), np.float64(47.7385476988523)):
#     Total rate = 32.85 kHz, pure rate: 2.44 kHz
#     Total eff: 93.47%, pure eff: 1.66%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(29.44980728000177), np.float64(52.04104109883003), np.float64(34.94642465492301)):
#     Total rate = 106.67 kHz, pure rate: 59.54 kHz
#     Total eff: 96.43%, pure eff: 4.62%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.530104344790537), np.float64(48.606985834615486), np.float64(129.7073194625498)):
#     Total rate = 9.66 kHz, pure rate: 0.03 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(60.70598112796528), np.float64(94.36951547396951), np.float64(147.30604293776753)):
#     Total rate = 1.91 kHz, pure rate: 0.00 kHz
#     Total eff: 91.87%, pure eff: 0.06%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.252888447675346), np.float64(156.6665841621274), np.float64(135.93115738161794)):
#     Total rate = 5.17 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(59.644416470974804), np.float64(146.29560994195253), np.float64(88.05775101573848)):
#     Total rate = 3.51 kHz, pure rate: 0.03 kHz
#     Total eff: 92.06%, pure eff: 0.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(53.18696653988104), np.float64(75.02362440844341), np.float64(107.03178272025528)):
#     Total rate = 5.03 kHz, pure rate: 0.09 kHz
#     Total eff: 92.36%, pure eff: 0.55%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.32081631433239), np.float64(63.87706841736852), np.float64(51.370928799210816)):
#     Total rate = 40.66 kHz, pure rate: 13.61 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(16.393970508353963), np.float64(153.779853402492), np.float64(142.99118908895682)):
#     Total rate = 6.22 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(17.747866208087046), np.float64(142.72926445804657), np.float64(134.91457214464597)):
#     Total rate = 8.11 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(32.82073452413724), np.float64(32.75835003742934), np.float64(29.519662547050203)):
#     Total rate = 67.57 kHz, pure rate: 31.81 kHz
#     Total eff: 96.06%, pure eff: 4.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.62166589164849), np.float64(67.64064257282553), np.float64(94.4479957643607)):
#     Total rate = 33.18 kHz, pure rate: 1.19 kHz
#     Total eff: 93.66%, pure eff: 1.85%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(40.364367522480656), np.float64(134.66164046883162), np.float64(69.88479794456278)):
#     Total rate = 11.76 kHz, pure rate: 0.28 kHz
#     Total eff: 92.86%, pure eff: 1.05%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.184591373756977), np.float64(106.50221795611422), np.float64(52.51249182862865)):
#     Total rate = 45.45 kHz, pure rate: 7.67 kHz
#     Total eff: 94.89%, pure eff: 3.08%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(55.46222234781827), np.float64(100.50387229472531), np.float64(102.76716458060221)):
#     Total rate = 4.51 kHz, pure rate: 0.11 kHz
#     Total eff: 92.67%, pure eff: 0.86%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(6.825833431223327), np.float64(110.75012959927649), np.float64(59.14435493975137)):
#     Total rate = 56.24 kHz, pure rate: 7.09 kHz
#     Total eff: 94.77%, pure eff: 2.96%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(0.2773851796817439), np.float64(82.70999794643416), np.float64(116.71318537857722)):
#     Total rate = 15.25 kHz, pure rate: 0.25 kHz
#     Total eff: 92.12%, pure eff: 0.31%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(63.246340438733526), np.float64(89.39701341543082), np.float64(124.87300677746202)):
#     Total rate = 2.32 kHz, pure rate: 0.00 kHz
#     Total eff: 91.81%, pure eff: 0.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(66.76207669631987), np.float64(55.43294914370312), np.float64(65.61416948151157)):
#     Total rate = 2.49 kHz, pure rate: 0.02 kHz
#     Total eff: 92.18%, pure eff: 0.37%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(50.94930594251632), np.float64(137.94380849877493), np.float64(45.955944673061076)):
#     Total rate = 6.67 kHz, pure rate: 0.13 kHz
#     Total eff: 92.73%, pure eff: 0.92%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.894953887553555), np.float64(117.78237169574359), np.float64(109.89161674166672)):
#     Total rate = 18.99 kHz, pure rate: 0.36 kHz
#     Total eff: 92.30%, pure eff: 0.49%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(64.0190911302094), np.float64(80.12757711368357), np.float64(67.14750501760591)):
#     Total rate = 3.13 kHz, pure rate: 0.05 kHz
#     Total eff: 92.49%, pure eff: 0.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(52.617058821042775), np.float64(123.63715818200647), np.float64(41.867601890875)):
#     Total rate = 6.94 kHz, pure rate: 0.27 kHz
#     Total eff: 93.17%, pure eff: 1.35%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(11.975459671361527), np.float64(112.65611802310505), np.float64(80.26110151614665)):
#     Total rate = 39.09 kHz, pure rate: 1.93 kHz
#     Total eff: 93.90%, pure eff: 2.09%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(68.72286385273873), np.float64(133.73566827925825), np.float64(21.94702613847501)):
#     Total rate = 2.11 kHz, pure rate: 0.00 kHz
#     Total eff: 92.06%, pure eff: 0.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(9.041708048713538), np.float64(41.96178197239228), np.float64(74.73400158034481)):
#     Total rate = 79.55 kHz, pure rate: 10.87 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(47.16158640878208), np.float64(104.21312131468885), np.float64(103.86932834831242)):
#     Total rate = 7.33 kHz, pure rate: 0.20 kHz
#     Total eff: 92.73%, pure eff: 0.92%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(46.342586514872124), np.float64(97.38008285349473), np.float64(62.80543773731851)):
#     Total rate = 11.41 kHz, pure rate: 0.96 kHz
#     Total eff: 94.09%, pure eff: 2.28%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(24.311260230008465), np.float64(114.97198684330985), np.float64(89.71901029589462)):
#     Total rate = 26.51 kHz, pure rate: 0.92 kHz
#     Total eff: 93.35%, pure eff: 1.54%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(3.977711154355731), np.float64(36.97625833524822), np.float64(113.06025895880404)):
#     Total rate = 16.97 kHz, pure rate: 0.30 kHz
#     Total eff: 92.30%, pure eff: 0.49%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(2.20017254320031), np.float64(149.40975051679396), np.float64(118.98053227183189)):
#     Total rate = 10.54 kHz, pure rate: 0.02 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(58.38719664922003), np.float64(44.824596436859785), np.float64(145.66667921595558)):
#     Total rate = 2.07 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(67.81351541584876), np.float64(157.39777029618767), np.float64(55.04626022623651)):
#     Total rate = 2.00 kHz, pure rate: 0.00 kHz
#     Total eff: 91.81%, pure eff: 0.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(57.329018515895626), np.float64(34.675229074014624), np.float64(28.199340881065197)):
#     Total rate = 5.45 kHz, pure rate: 0.27 kHz
#     Total eff: 93.17%, pure eff: 1.35%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.418771879407224), np.float64(70.95090077073925), np.float64(96.09341929872366)):
#     Total rate = 13.64 kHz, pure rate: 0.53 kHz
#     Total eff: 93.35%, pure eff: 1.54%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(44.256906754428215), np.float64(78.76404747954948), np.float64(100.030071559132)):
#     Total rate = 9.10 kHz, pure rate: 0.33 kHz
#     Total eff: 93.04%, pure eff: 1.23%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(41.13244282859267), np.float64(39.769058491201854), np.float64(121.3687192469308)):
#     Total rate = 7.25 kHz, pure rate: 0.13 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.590275889467247), np.float64(114.64805269096878), np.float64(100.1914328875904)):
#     Total rate = 19.43 kHz, pure rate: 0.49 kHz
#     Total eff: 92.98%, pure eff: 1.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(43.93288711336421), np.float64(148.3144634683375), np.float64(127.57635664945221)):
#     Total rate = 5.12 kHz, pure rate: 0.02 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(29.960286947330633), np.float64(143.04831587274452), np.float64(67.76196747264099)):
#     Total rate = 16.36 kHz, pure rate: 0.25 kHz
#     Total eff: 92.61%, pure eff: 0.80%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(59.644416470974804), np.float64(146.29560994195253), np.float64(84.02052388954988)):
#     Total rate = 3.62 kHz, pure rate: 0.03 kHz
#     Total eff: 92.06%, pure eff: 0.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(1.2080834221461245), np.float64(127.5559436862543), np.float64(47.7385476988523)):
#     Total rate = 37.95 kHz, pure rate: 2.68 kHz
#     Total eff: 93.53%, pure eff: 1.72%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(67.54900510701518), np.float64(128.3815422285836), np.float64(130.3402916395396)):
#     Total rate = 1.85 kHz, pure rate: 0.00 kHz
#     Total eff: 91.81%, pure eff: 0.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.332241240693293), np.float64(49.42971724465815), np.float64(97.68039207328982)):
#     Total rate = 28.43 kHz, pure rate: 0.88 kHz
#     Total eff: 93.47%, pure eff: 1.66%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.252888447675346), np.float64(38.46198534644503), np.float64(135.93115738161794)):
#     Total rate = 5.81 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(31.359872356929003), np.float64(156.91694643284816), np.float64(77.3012861685365)):
#     Total rate = 10.71 kHz, pure rate: 0.05 kHz
#     Total eff: 92.06%, pure eff: 0.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(24.74432234967455), np.float64(92.18964525431612), np.float64(87.09149771152643)):
#     Total rate = 33.91 kHz, pure rate: 1.75 kHz
#     Total eff: 94.15%, pure eff: 2.34%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(9.697911049016739), np.float64(55.94551393243997), np.float64(62.64548511090997)):
#     Total rate = 153.17 kHz, pure rate: 60.81 kHz
#     Total eff: 96.55%, pure eff: 4.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(48.29379098387132), np.float64(45.847279366278336), np.float64(147.30604293776753)):
#     Total rate = 3.18 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(51.43919634862428), np.float64(118.0030466527476), np.float64(104.86781977474496)):
#     Total rate = 5.50 kHz, pure rate: 0.09 kHz
#     Total eff: 92.49%, pure eff: 0.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(43.784981114453814), np.float64(65.26252997463884), np.float64(24.024193025359672)):
#     Total rate = 17.30 kHz, pure rate: 3.51 kHz
#     Total eff: 94.70%, pure eff: 2.89%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(60.59648489143908), np.float64(48.606985834615486), np.float64(68.91234943930462)):
#     Total rate = 4.02 kHz, pure rate: 0.09 kHz
#     Total eff: 92.67%, pure eff: 0.86%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.290570604234475), np.float64(99.13338025971603), np.float64(76.90267975126577)):
#     Total rate = 35.92 kHz, pure rate: 2.65 kHz
#     Total eff: 94.46%, pure eff: 2.65%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.264042444875088), np.float64(82.70999794643416), np.float64(59.3401034103688)):
#     Total rate = 64.99 kHz, pure rate: 18.96 kHz
#     Total eff: 96.00%, pure eff: 4.19%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(68.05843115607723), np.float64(142.72926445804657), np.float64(53.591917341920656)):
#     Total rate = 2.19 kHz, pure rate: 0.00 kHz
#     Total eff: 91.87%, pure eff: 0.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(19.257567366829612), np.float64(67.64064257282553), np.float64(144.52118544853843)):
#     Total rate = 6.06 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(4.254810355648921), np.float64(30.67949633059554), np.float64(29.519662547050203)):
#     Total rate = 2897.70 kHz, pure rate: 2702.46 kHz
#     Total eff: 97.54%, pure eff: 5.73%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(60.44762563472676), np.float64(89.39701341543082), np.float64(124.87300677746202)):
#     Total rate = 2.74 kHz, pure rate: 0.00 kHz
#     Total eff: 91.87%, pure eff: 0.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(31.300832817749026), np.float64(36.23025982907641), np.float64(59.14435493975137)):
#     Total rate = 54.83 kHz, pure rate: 19.13 kHz
#     Total eff: 96.00%, pure eff: 4.19%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(52.617058821042775), np.float64(69.24170983589481), np.float64(41.867601890875)):
#     Total rate = 7.67 kHz, pure rate: 0.63 kHz
#     Total eff: 93.66%, pure eff: 1.85%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.074982844822383), np.float64(54.20841205388685), np.float64(115.04854019557169)):
#     Total rate = 15.81 kHz, pure rate: 0.27 kHz
#     Total eff: 92.18%, pure eff: 0.37%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(45.02066920818672), np.float64(84.52128110064122), np.float64(108.00291019357357)):
#     Total rate = 7.62 kHz, pure rate: 0.20 kHz
#     Total eff: 92.49%, pure eff: 0.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(66.76207669631987), np.float64(106.23841378664862), np.float64(49.89339061955624)):
#     Total rate = 2.51 kHz, pure rate: 0.03 kHz
#     Total eff: 92.18%, pure eff: 0.37%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(40.364367522480656), np.float64(138.15405092909822), np.float64(105.59509736571411)):
#     Total rate = 8.20 kHz, pure rate: 0.06 kHz
#     Total eff: 92.30%, pure eff: 0.49%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.184591373756977), np.float64(105.37221626139208), np.float64(101.19007717757367)):
#     Total rate = 20.35 kHz, pure rate: 0.55 kHz
#     Total eff: 92.98%, pure eff: 1.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(55.46222234781827), np.float64(69.90235898927942), np.float64(146.4369270030103)):
#     Total rate = 2.25 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(11.975459671361527), np.float64(101.82523277588936), np.float64(102.46332906993918)):
#     Total rate = 24.39 kHz, pure rate: 0.66 kHz
#     Total eff: 92.98%, pure eff: 1.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.894953887553555), np.float64(52.57073236105249), np.float64(38.3796005765235)):
#     Total rate = 650.07 kHz, pure rate: 507.34 kHz
#     Total eff: 97.35%, pure eff: 5.54%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(58.15086240197678), np.float64(80.12757711368357), np.float64(42.77795458640695)):
#     Total rate = 5.01 kHz, pure rate: 0.23 kHz
#     Total eff: 93.04%, pure eff: 1.23%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(19.843289914276195), np.float64(100.78584581974602), np.float64(34.37932186430753)):
#     Total rate = 79.28 kHz, pure rate: 22.42 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(33.694158796107224), np.float64(73.8585404360796), np.float64(78.47620595195659)):
#     Total rate = 27.85 kHz, pure rate: 3.19 kHz
#     Total eff: 94.64%, pure eff: 2.83%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.24156683562273), np.float64(93.54152374580866), np.float64(74.73400158034481)):
#     Total rate = 50.87 kHz, pure rate: 4.96 kHz
#     Total eff: 95.01%, pure eff: 3.20%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(46.342586514872124), np.float64(52.904306949869365), np.float64(48.65969419040031)):
#     Total rate = 13.01 kHz, pure rate: 1.96 kHz
#     Total eff: 94.21%, pure eff: 2.40%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(4.906931055843586), np.float64(36.97625833524822), np.float64(113.59355317595394)):
#     Total rate = 16.72 kHz, pure rate: 0.28 kHz
#     Total eff: 92.24%, pure eff: 0.43%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.41493289197842), np.float64(111.80172873533634), np.float64(50.146355302928434)):
#     Total rate = 21.12 kHz, pure rate: 2.46 kHz
#     Total eff: 94.27%, pure eff: 2.46%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.949839412354532), np.float64(77.0700154665504), np.float64(55.04626022623651)):
#     Total rate = 162.67 kHz, pure rate: 65.91 kHz
#     Total eff: 96.98%, pure eff: 5.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.356926595536919), np.float64(42.08033493122097), np.float64(148.5563115445388)):
#     Total rate = 5.87 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.456010864616754), np.float64(149.40975051679396), np.float64(115.41790674835961)):
#     Total rate = 10.29 kHz, pure rate: 0.02 kHz
#     Total eff: 92.00%, pure eff: 0.18%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(17.620285417366613), np.float64(138.30526579621656), np.float64(145.66667921595558)):
#     Total rate = 6.01 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(56.11126596281065), np.float64(45.57621167042728), np.float64(28.199340881065197)):
#     Total rate = 5.95 kHz, pure rate: 0.33 kHz
#     Total eff: 93.41%, pure eff: 1.60%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(2.6710240022886182), np.float64(110.09821386438978), np.float64(132.6997587612019)):
#     Total rate = 9.28 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(9.870850782862671), np.float64(41.18749000829601), np.float64(142.6010728722484)):
#     Total rate = 6.70 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# differential_evolution step 1: f(x)= -0.03325123152709353
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.216318739856025), np.float64(149.12780969484612), np.float64(86.89126824810727)):
#     Total rate = 15.88 kHz, pure rate: 0.09 kHz
#     Total eff: 92.06%, pure eff: 0.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(30.045201998344794), np.float64(39.36839106459476), np.float64(31.731481907481147)):
#     Total rate = 101.75 kHz, pure rate: 56.50 kHz
#     Total eff: 96.31%, pure eff: 4.50%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(19.442962230140843), np.float64(109.60604546764121), np.float64(86.24319590194645)):
#     Total rate = 33.77 kHz, pure rate: 1.42 kHz
#     Total eff: 93.66%, pure eff: 1.85%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(61.619190446717894), np.float64(50.505404942790285), np.float64(70.41749016916151)):
#     Total rate = 3.74 kHz, pure rate: 0.06 kHz
#     Total eff: 92.55%, pure eff: 0.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.673641402882048), np.float64(96.02295054418842), np.float64(67.76196747264099)):
#     Total rate = 67.78 kHz, pure rate: 9.17 kHz
#     Total eff: 95.38%, pure eff: 3.57%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.025240206370754), np.float64(85.24489309583312), np.float64(106.61246102102692)):
#     Total rate = 19.79 kHz, pure rate: 0.47 kHz
#     Total eff: 92.49%, pure eff: 0.68%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.332241240693293), np.float64(56.22898210738553), np.float64(77.14476409374019)):
#     Total rate = 67.31 kHz, pure rate: 7.22 kHz
#     Total eff: 95.20%, pure eff: 3.39%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.54579384927899), np.float64(147.82201187893745), np.float64(61.35064482516422)):
#     Total rate = 19.38 kHz, pure rate: 0.27 kHz
#     Total eff: 92.49%, pure eff: 0.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(42.334903977331756), np.float64(45.847279366278336), np.float64(49.29251760704809)):
#     Total rate = 19.32 kHz, pure rate: 4.15 kHz
#     Total eff: 94.83%, pure eff: 3.02%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(7.717903617081685), np.float64(88.64177472289077), np.float64(56.921406834942786)):
#     Total rate = 110.82 kHz, pure rate: 31.80 kHz
#     Total eff: 96.49%, pure eff: 4.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(16.60021343214209), np.float64(58.35885684040111), np.float64(83.52232722061906)):
#     Total rate = 49.27 kHz, pure rate: 3.29 kHz
#     Total eff: 94.64%, pure eff: 2.83%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(23.863316705368295), np.float64(38.46198534644503), np.float64(135.93115738161794)):
#     Total rate = 7.75 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.861641317414428), np.float64(95.89880939970149), np.float64(50.490616805980245)):
#     Total rate = 58.79 kHz, pure rate: 14.75 kHz
#     Total eff: 95.44%, pure eff: 3.63%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.52390443097011), np.float64(55.94551393243997), np.float64(88.01219281482763)):
#     Total rate = 30.14 kHz, pure rate: 1.52 kHz
#     Total eff: 94.09%, pure eff: 2.28%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(32.752561918376344), np.float64(76.2247477525578), np.float64(68.69195698968124)):
#     Total rate = 37.47 kHz, pure rate: 7.97 kHz
#     Total eff: 95.50%, pure eff: 3.69%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(31.496499330371577), np.float64(77.07625685991326), np.float64(101.20172197778454)):
#     Total rate = 17.27 kHz, pure rate: 0.50 kHz
#     Total eff: 93.04%, pure eff: 1.23%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(44.340180665301794), np.float64(42.42243432257857), np.float64(73.06539484560813)):
#     Total rate = 13.09 kHz, pure rate: 1.27 kHz
#     Total eff: 94.21%, pure eff: 2.40%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(45.02066920818672), np.float64(88.83922175798627), np.float64(78.63987858455839)):
#     Total rate = 11.55 kHz, pure rate: 0.80 kHz
#     Total eff: 93.90%, pure eff: 2.09%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(15.467808109806619), np.float64(67.78090832879474), np.float64(80.87578886203366)):
#     Total rate = 56.55 kHz, pure rate: 4.67 kHz
#     Total eff: 94.83%, pure eff: 3.02%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(17.747866208087046), np.float64(48.691919728361206), np.float64(80.72707419477699)):
#     Total rate = 54.70 kHz, pure rate: 4.62 kHz
#     Total eff: 94.77%, pure eff: 2.96%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.797120955293675), np.float64(55.44463050076382), np.float64(29.519662547050203)):
#     Total rate = 851.51 kHz, pure rate: 696.89 kHz
#     Total eff: 97.41%, pure eff: 5.60%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.358990147283983), np.float64(88.27581813759477), np.float64(45.67526522239615)):
#     Total rate = 104.15 kHz, pure rate: 36.48 kHz
#     Total eff: 96.49%, pure eff: 4.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(42.73178906824701), np.float64(80.86572269651222), np.float64(41.72841086381247)):
#     Total rate = 18.46 kHz, pure rate: 3.57 kHz
#     Total eff: 94.70%, pure eff: 2.89%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(30.200458002279078), np.float64(102.76183831533174), np.float64(56.513674258665546)):
#     Total rate = 38.55 kHz, pure rate: 6.51 kHz
#     Total eff: 95.14%, pure eff: 3.33%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.743183015932782), np.float64(65.3945641430808), np.float64(108.66549553219672)):
#     Total rate = 20.02 kHz, pure rate: 0.39 kHz
#     Total eff: 92.49%, pure eff: 0.68%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.364861508285692), np.float64(145.78510003873322), np.float64(78.87519364142011)):
#     Total rate = 17.97 kHz, pure rate: 0.13 kHz
#     Total eff: 92.24%, pure eff: 0.43%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.954822846016288), np.float64(106.50221795611422), np.float64(90.35568012493704)):
#     Total rate = 25.77 kHz, pure rate: 0.96 kHz
#     Total eff: 93.60%, pure eff: 1.79%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.04495443170265), np.float64(71.83144402491098), np.float64(42.77795458640695)):
#     Total rate = 43.40 kHz, pure rate: 15.17 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.42075832360315), np.float64(30.1175366667715), np.float64(45.955944673061076)):
#     Total rate = 33.83 kHz, pure rate: 10.65 kHz
#     Total eff: 95.57%, pure eff: 3.76%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.537677452168069), np.float64(82.70999794643416), np.float64(101.23599169173012)):
#     Total rate = 25.39 kHz, pure rate: 0.72 kHz
#     Total eff: 93.10%, pure eff: 1.29%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(21.57742633002716), np.float64(51.421435913147526), np.float64(66.01239104853806)):
#     Total rate = 88.74 kHz, pure rate: 26.88 kHz
#     Total eff: 96.18%, pure eff: 4.37%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.894953887553555), np.float64(36.415089247569064), np.float64(90.02474863088398)):
#     Total rate = 39.78 kHz, pure rate: 1.99 kHz
#     Total eff: 94.09%, pure eff: 2.28%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.442525744889586), np.float64(111.80172873533634), np.float64(67.6471300017327)):
#     Total rate = 40.19 kHz, pure rate: 3.54 kHz
#     Total eff: 94.40%, pure eff: 2.59%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(29.638990264987378), np.float64(68.14405569057791), np.float64(78.53134305189748)):
#     Total rate = 36.45 kHz, pure rate: 4.10 kHz
#     Total eff: 94.70%, pure eff: 2.89%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.37543919793888), np.float64(35.121465209192486), np.float64(116.54486171692878)):
#     Total rate = 9.69 kHz, pure rate: 0.17 kHz
#     Total eff: 92.12%, pure eff: 0.31%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(28.213004267528966), np.float64(64.36121410204316), np.float64(62.93011059251242)):
#     Total rate = 65.33 kHz, pure rate: 21.64 kHz
#     Total eff: 96.00%, pure eff: 4.19%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(0.8731025794532599), np.float64(133.73566827925825), np.float64(120.8948883362088)):
#     Total rate = 12.38 kHz, pure rate: 0.05 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.097640880895735), np.float64(74.98364590887144), np.float64(64.05559493906833)):
#     Total rate = 118.28 kHz, pure rate: 36.43 kHz
#     Total eff: 96.49%, pure eff: 4.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(34.14648892188301), np.float64(32.39081537890171), np.float64(119.89821884244682)):
#     Total rate = 9.77 kHz, pure rate: 0.16 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.80272970627463), np.float64(33.169425627536874), np.float64(74.66670612078836)):
#     Total rate = 74.73 kHz, pure rate: 9.97 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.979620981809184), np.float64(84.40033163848202), np.float64(57.99499847774132)):
#     Total rate = 115.42 kHz, pure rate: 35.35 kHz
#     Total eff: 96.55%, pure eff: 4.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.418771879407224), np.float64(38.21630832612719), np.float64(100.11739517064808)):
#     Total rate = 12.40 kHz, pure rate: 0.41 kHz
#     Total eff: 93.10%, pure eff: 1.29%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.67644120616354), np.float64(45.57621167042728), np.float64(88.17326168952947)):
#     Total rate = 37.89 kHz, pure rate: 1.86 kHz
#     Total eff: 94.15%, pure eff: 2.34%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.84761283458055), np.float64(72.81548469079141), np.float64(61.81464320860837)):
#     Total rate = 29.43 kHz, pure rate: 6.98 kHz
#     Total eff: 95.44%, pure eff: 3.63%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(43.89334475758807), np.float64(85.553609684492), np.float64(83.24682842620778)):
#     Total rate = 11.95 kHz, pure rate: 0.78 kHz
#     Total eff: 93.84%, pure eff: 2.03%
# differential_evolution step 2: f(x)= -0.0387931034482758
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(3.096853025921), np.float64(64.76095686966052), np.float64(60.13962912193273)):
#     Total rate = 177.34 kHz, pure rate: 78.28 kHz
#     Total eff: 96.67%, pure eff: 4.86%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.78322857138205), np.float64(88.6012070204975), np.float64(78.77230508494158)):
#     Total rate = 47.72 kHz, pure rate: 4.34 kHz
#     Total eff: 94.83%, pure eff: 3.02%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.332241240693293), np.float64(65.87204215902473), np.float64(33.82240059007723)):
#     Total rate = 363.63 kHz, pure rate: 249.22 kHz
#     Total eff: 97.17%, pure eff: 5.36%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(25.076762242347545), np.float64(138.3034578083855), np.float64(30.756485203368634)):
#     Total rate = 23.23 kHz, pure rate: 0.91 kHz
#     Total eff: 92.86%, pure eff: 1.05%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.412519513686608), np.float64(128.2990532697526), np.float64(21.071202549434297)):
#     Total rate = 28.74 kHz, pure rate: 2.33 kHz
#     Total eff: 93.35%, pure eff: 1.54%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(24.058900164197226), np.float64(114.12533095148424), np.float64(131.75752225122466)):
#     Total rate = 8.97 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.946131718273406), np.float64(92.18964525431612), np.float64(22.119858618119224)):
#     Total rate = 158.85 kHz, pure rate: 68.93 kHz
#     Total eff: 96.55%, pure eff: 4.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.328881982359633), np.float64(67.97483547497444), np.float64(77.29247133487915)):
#     Total rate = 69.55 kHz, pure rate: 7.50 kHz
#     Total eff: 95.14%, pure eff: 3.33%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(34.49424547298477), np.float64(82.61157106883095), np.float64(83.52232722061906)):
#     Total rate = 23.73 kHz, pure rate: 1.91 kHz
#     Total eff: 94.33%, pure eff: 2.52%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(34.953118196237234), np.float64(67.33664151733413), np.float64(64.41349334797985)):
#     Total rate = 34.58 kHz, pure rate: 8.63 kHz
#     Total eff: 95.63%, pure eff: 3.82%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(21.2274672678449), np.float64(68.23732924075767), np.float64(135.93115738161794)):
#     Total rate = 7.91 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(43.784981114453814), np.float64(65.26252997463884), np.float64(86.49373039111819)):
#     Total rate = 11.51 kHz, pure rate: 0.64 kHz
#     Total eff: 93.78%, pure eff: 1.97%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(52.058207973195714), np.float64(74.29691198135744), np.float64(84.3834453128836)):
#     Total rate = 6.94 kHz, pure rate: 0.36 kHz
#     Total eff: 93.41%, pure eff: 1.60%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(31.496499330371577), np.float64(107.54484219881205), np.float64(101.20172197778454)):
#     Total rate = 17.13 kHz, pure rate: 0.50 kHz
#     Total eff: 92.98%, pure eff: 1.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(55.608565095274884), np.float64(46.812985238530146), np.float64(38.54150480101514)):
#     Total rate = 6.06 kHz, pure rate: 0.39 kHz
#     Total eff: 93.47%, pure eff: 1.66%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.52390443097011), np.float64(30.143584001558025), np.float64(81.89812307562522)):
#     Total rate = 36.90 kHz, pure rate: 3.13 kHz
#     Total eff: 94.52%, pure eff: 2.71%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.96394378092802), np.float64(116.21688982841584), np.float64(85.37710853232733)):
#     Total rate = 30.28 kHz, pure rate: 1.11 kHz
#     Total eff: 93.53%, pure eff: 1.72%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(60.4195218144786), np.float64(131.22476665345349), np.float64(101.23599169173012)):
#     Total rate = 3.16 kHz, pure rate: 0.00 kHz
#     Total eff: 92.24%, pure eff: 0.43%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(18.02802986457989), np.float64(34.960506408281425), np.float64(132.45790856413137)):
#     Total rate = 9.11 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(43.054283546001535), np.float64(84.04269158031062), np.float64(82.99935178109571)):
#     Total rate = 12.71 kHz, pure rate: 0.89 kHz
#     Total eff: 93.97%, pure eff: 2.16%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.61411296141576), np.float64(53.420014864783), np.float64(45.955944673061076)):
#     Total rate = 406.33 kHz, pure rate: 285.01 kHz
#     Total eff: 97.17%, pure eff: 5.36%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(40.25188241536812), np.float64(80.86572269651222), np.float64(34.71762668939026)):
#     Total rate = 24.05 kHz, pure rate: 5.71 kHz
#     Total eff: 95.01%, pure eff: 3.20%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.19453204361072), np.float64(47.46671968640001), np.float64(93.06882487179227)):
#     Total rate = 14.73 kHz, pure rate: 0.69 kHz
#     Total eff: 93.47%, pure eff: 1.66%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.184591373756977), np.float64(50.21218532963293), np.float64(96.40841324445046)):
#     Total rate = 23.61 kHz, pure rate: 0.69 kHz
#     Total eff: 93.41%, pure eff: 1.60%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(3.04853467914894), np.float64(51.984776877225194), np.float64(78.87519364142011)):
#     Total rate = 66.65 kHz, pure rate: 6.94 kHz
#     Total eff: 95.01%, pure eff: 3.20%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(19.951182586236182), np.float64(98.87752755993857), np.float64(75.49054034372976)):
#     Total rate = 48.63 kHz, pure rate: 3.73 kHz
#     Total eff: 94.77%, pure eff: 2.96%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(8.673195032160809), np.float64(130.48798695608318), np.float64(42.77795458640695)):
#     Total rate = 35.73 kHz, pure rate: 2.36 kHz
#     Total eff: 93.29%, pure eff: 1.48%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(30.11576409306177), np.float64(100.50387229472531), np.float64(47.152418945685625)):
#     Total rate = 43.78 kHz, pure rate: 9.35 kHz
#     Total eff: 95.20%, pure eff: 3.39%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.41436834807508), np.float64(95.08919631955874), np.float64(110.55161523740108)):
#     Total rate = 16.78 kHz, pure rate: 0.33 kHz
#     Total eff: 92.30%, pure eff: 0.49%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.956663179468116), np.float64(46.62248640005092), np.float64(90.02474863088398)):
#     Total rate = 14.84 kHz, pure rate: 0.86 kHz
#     Total eff: 93.72%, pure eff: 1.91%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.778034691453136), np.float64(112.65611802310505), np.float64(37.343391903481056)):
#     Total rate = 24.39 kHz, pure rate: 3.15 kHz
#     Total eff: 94.27%, pure eff: 2.46%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(66.76207669631987), np.float64(104.89073206793205), np.float64(125.41071572539583)):
#     Total rate = 1.97 kHz, pure rate: 0.00 kHz
#     Total eff: 91.81%, pure eff: 0.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(6.003477405389813), np.float64(100.89690619564304), np.float64(90.47515123826166)):
#     Total rate = 36.90 kHz, pure rate: 1.68 kHz
#     Total eff: 93.90%, pure eff: 2.09%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(42.80592006747873), np.float64(74.96425276583287), np.float64(78.8587163040634)):
#     Total rate = 13.65 kHz, pure rate: 1.22 kHz
#     Total eff: 94.15%, pure eff: 2.34%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(26.800141416349383), np.float64(38.99476088095462), np.float64(25.86152993438334)):
#     Total rate = 180.88 kHz, pure rate: 120.18 kHz
#     Total eff: 96.61%, pure eff: 4.80%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(65.25016534256679), np.float64(63.04262275040198), np.float64(117.14295103508795)):
#     Total rate = 2.16 kHz, pure rate: 0.00 kHz
#     Total eff: 91.87%, pure eff: 0.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.473825169982014), np.float64(52.904306949869365), np.float64(126.25511945918674)):
#     Total rate = 7.67 kHz, pure rate: 0.06 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(6.649372938773361), np.float64(61.64270230792322), np.float64(21.19930073408736)):
#     Total rate = 744.18 kHz, pure rate: 593.22 kHz
#     Total eff: 97.48%, pure eff: 5.67%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(34.14648892188301), np.float64(42.21771078333306), np.float64(104.45106956808226)):
#     Total rate = 13.97 kHz, pure rate: 0.36 kHz
#     Total eff: 92.61%, pure eff: 0.80%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(9.132984276200055), np.float64(149.1048807650752), np.float64(70.8435988029461)):
#     Total rate = 18.24 kHz, pure rate: 0.19 kHz
#     Total eff: 92.30%, pure eff: 0.49%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.258029874329836), np.float64(72.81548469079141), np.float64(61.81464320860837)):
#     Total rate = 137.62 kHz, pure rate: 49.38 kHz
#     Total eff: 96.55%, pure eff: 4.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.671750018967025), np.float64(91.24347661607598), np.float64(42.80622992596632)):
#     Total rate = 129.74 kHz, pure rate: 46.58 kHz
#     Total eff: 96.49%, pure eff: 4.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.170970498277093), np.float64(62.41311278727173), np.float64(56.718532145304096)):
#     Total rate = 205.55 kHz, pure rate: 105.29 kHz
#     Total eff: 96.98%, pure eff: 5.17%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(28.0695079114145), np.float64(70.95090077073925), np.float64(71.85821285023339)):
#     Total rate = 49.49 kHz, pure rate: 9.41 kHz
#     Total eff: 95.44%, pure eff: 3.63%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(40.17753337171136), np.float64(85.553609684492), np.float64(128.31902832810067)):
#     Total rate = 6.45 kHz, pure rate: 0.05 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# differential_evolution step 3: f(x)= -0.0387931034482758
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(28.672162439213896), np.float64(45.968552095209056), np.float64(84.6487123300142)):
#     Total rate = 31.63 kHz, pure rate: 2.05 kHz
#     Total eff: 94.40%, pure eff: 2.59%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.81517476333886), np.float64(33.169425627536874), np.float64(28.614150907191828)):
#     Total rate = 149.94 kHz, pure rate: 94.41 kHz
#     Total eff: 96.55%, pure eff: 4.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(23.51643497044774), np.float64(84.9000503776815), np.float64(24.024193025359672)):
#     Total rate = 117.00 kHz, pure rate: 52.25 kHz
#     Total eff: 96.61%, pure eff: 4.80%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(32.520871205945866), np.float64(147.92938811863135), np.float64(46.14218930818894)):
#     Total rate = 14.45 kHz, pure rate: 0.28 kHz
#     Total eff: 92.43%, pure eff: 0.62%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(40.61775791030084), np.float64(41.087238842032555), np.float64(83.52232722061906)):
#     Total rate = 15.03 kHz, pure rate: 1.05 kHz
#     Total eff: 94.03%, pure eff: 2.22%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.439823279121647), np.float64(73.18306306364225), np.float64(94.32586286377268)):
#     Total rate = 28.49 kHz, pure rate: 1.02 kHz
#     Total eff: 93.60%, pure eff: 1.79%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.412519513686608), np.float64(120.51806733244054), np.float64(103.00641509818531)):
#     Total rate = 17.61 kHz, pure rate: 0.41 kHz
#     Total eff: 92.73%, pure eff: 0.92%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(27.69022193527901), np.float64(88.6012070204975), np.float64(90.62572298106349)):
#     Total rate = 27.04 kHz, pure rate: 1.21 kHz
#     Total eff: 93.84%, pure eff: 2.03%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(24.937357848377776), np.float64(140.37649836788495), np.float64(77.14476409374019)):
#     Total rate = 18.49 kHz, pure rate: 0.23 kHz
#     Total eff: 92.55%, pure eff: 0.74%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.325852932093628), np.float64(120.82692888914069), np.float64(129.40448439438396)):
#     Total rate = 10.29 kHz, pure rate: 0.03 kHz
#     Total eff: 91.93%, pure eff: 0.12%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(8.077214008132248), np.float64(43.071882373819015), np.float64(92.63011279238884)):
#     Total rate = 36.09 kHz, pure rate: 1.52 kHz
#     Total eff: 93.78%, pure eff: 1.97%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(22.36380962684931), np.float64(60.95844475878671), np.float64(62.05841416608139)):
#     Total rate = 101.01 kHz, pure rate: 38.37 kHz
#     Total eff: 96.37%, pure eff: 4.56%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.547091700216715), np.float64(91.57928120840097), np.float64(134.41631066313715)):
#     Total rate = 8.42 kHz, pure rate: 0.00 kHz
#     Total eff: 91.93%, pure eff: 0.12%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(39.75962081849016), np.float64(49.59070061013259), np.float64(76.16896787434649)):
#     Total rate = 18.33 kHz, pure rate: 2.16 kHz
#     Total eff: 94.52%, pure eff: 2.71%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(32.54937021824258), np.float64(45.84051352267083), np.float64(55.6401409381925)):
#     Total rate = 52.06 kHz, pure rate: 18.93 kHz
#     Total eff: 96.06%, pure eff: 4.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(28.8633165920457), np.float64(109.00232538157793), np.float64(89.6201057870658)):
#     Total rate = 24.39 kHz, pure rate: 0.86 kHz
#     Total eff: 93.53%, pure eff: 1.72%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(17.747866208087046), np.float64(56.137739499548886), np.float64(80.72707419477699)):
#     Total rate = 54.70 kHz, pure rate: 4.62 kHz
#     Total eff: 94.77%, pure eff: 2.96%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(1.0928819506615142), np.float64(71.95967842294371), np.float64(20.387310523275673)):
#     Total rate = 440.27 kHz, pure rate: 303.95 kHz
#     Total eff: 97.48%, pure eff: 5.67%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.152110529894976), np.float64(68.20921009852552), np.float64(70.34873726006435)):
#     Total rate = 29.76 kHz, pure rate: 5.43 kHz
#     Total eff: 95.20%, pure eff: 3.39%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.68790816945629), np.float64(54.18357414137011), np.float64(86.13114473321598)):
#     Total rate = 46.66 kHz, pure rate: 2.82 kHz
#     Total eff: 94.33%, pure eff: 2.52%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(10.270442055004917), np.float64(123.80296406475028), np.float64(121.70160597824156)):
#     Total rate = 12.84 kHz, pure rate: 0.19 kHz
#     Total eff: 91.93%, pure eff: 0.12%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.62659125760025), np.float64(147.49555046689053), np.float64(80.87827728409366)):
#     Total rate = 17.14 kHz, pure rate: 0.09 kHz
#     Total eff: 92.24%, pure eff: 0.43%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(66.76207669631987), np.float64(65.4963723476977), np.float64(44.35413392519814)):
#     Total rate = 2.51 kHz, pure rate: 0.03 kHz
#     Total eff: 92.18%, pure eff: 0.37%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(29.952641360687558), np.float64(40.57036536383993), np.float64(63.98770088168317)):
#     Total rate = 54.97 kHz, pure rate: 16.78 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(20.30852291730544), np.float64(146.06061169741525), np.float64(37.343391903481056)):
#     Total rate = 20.10 kHz, pure rate: 0.38 kHz
#     Total eff: 92.43%, pure eff: 0.62%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(18.32259613375308), np.float64(145.49306943869053), np.float64(78.17370199701509)):
#     Total rate = 17.68 kHz, pure rate: 0.13 kHz
#     Total eff: 92.30%, pure eff: 0.49%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(54.71335369893865), np.float64(66.47699135963816), np.float64(67.8010282612153)):
#     Total rate = 6.23 kHz, pure rate: 0.42 kHz
#     Total eff: 93.60%, pure eff: 1.79%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(41.700826009493646), np.float64(61.75197040702284), np.float64(56.513674258665546)):
#     Total rate = 19.35 kHz, pure rate: 3.77 kHz
#     Total eff: 94.89%, pure eff: 3.08%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(50.94930594251632), np.float64(106.9806377795841), np.float64(57.878171330040175)):
#     Total rate = 8.00 kHz, pure rate: 0.36 kHz
#     Total eff: 93.90%, pure eff: 2.09%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(5.314710580561506), np.float64(36.50607594050589), np.float64(108.31826633604508)):
#     Total rate = 20.37 kHz, pure rate: 0.41 kHz
#     Total eff: 92.49%, pure eff: 0.68%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(14.585041632757633), np.float64(78.35318367218662), np.float64(71.03748106124104)):
#     Total rate = 86.33 kHz, pure rate: 15.12 kHz
#     Total eff: 95.94%, pure eff: 4.13%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.108654308525786), np.float64(74.97474694367564), np.float64(42.77795458640695)):
#     Total rate = 33.82 kHz, pure rate: 10.10 kHz
#     Total eff: 95.63%, pure eff: 3.82%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.814875050336216), np.float64(31.3026119952736), np.float64(69.07683663159999)):
#     Total rate = 102.42 kHz, pure rate: 24.47 kHz
#     Total eff: 96.06%, pure eff: 4.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(13.122285868329342), np.float64(33.66128464940571), np.float64(94.85709762114513)):
#     Total rate = 32.38 kHz, pure rate: 1.13 kHz
#     Total eff: 93.60%, pure eff: 1.79%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(6.671958926928951), np.float64(111.80172873533634), np.float64(69.21870026647991)):
#     Total rate = 47.97 kHz, pure rate: 3.87 kHz
#     Total eff: 94.40%, pure eff: 2.59%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(3.977711154355731), np.float64(32.938203944790764), np.float64(72.3710904371134)):
#     Total rate = 92.11 kHz, pure rate: 16.14 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.280125632270256), np.float64(44.86436144157444), np.float64(104.45106956808226)):
#     Total rate = 13.12 kHz, pure rate: 0.36 kHz
#     Total eff: 92.61%, pure eff: 0.80%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(46.342586514872124), np.float64(73.7464442304391), np.float64(84.49324711692093)):
#     Total rate = 10.04 kHz, pure rate: 0.63 kHz
#     Total eff: 93.66%, pure eff: 1.85%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(16.73871656503303), np.float64(45.57621167042728), np.float64(95.65295921523989)):
#     Total rate = 30.25 kHz, pure rate: 1.00 kHz
#     Total eff: 93.53%, pure eff: 1.72%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.84761283458055), np.float64(30.02419585905062), np.float64(67.37501803979781)):
#     Total rate = 27.23 kHz, pure rate: 5.42 kHz
#     Total eff: 95.26%, pure eff: 3.45%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(12.49160311769353), np.float64(73.8585404360796), np.float64(78.47620595195659)):
#     Total rate = 65.60 kHz, pure rate: 6.64 kHz
# ...
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.03084155425127), np.float64(76.96440492259671), np.float64(50.88504316569287)):
#     Total rate = 35.62 kHz, pure rate: 10.33 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.02778391905568), np.float64(76.63524739762337), np.float64(49.953001775237354)):
#     Total rate = 35.81 kHz, pure rate: 10.46 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.608104720112856), np.float64(71.206090857712), np.float64(53.118866373564245)):
#     Total rate = 33.46 kHz, pure rate: 9.49 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.1181844884538), np.float64(78.25941432396661), np.float64(52.78244634744464)):
#     Total rate = 34.13 kHz, pure rate: 9.46 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.51239000022387), np.float64(79.56890636739578), np.float64(53.331710552565326)):
#     Total rate = 35.85 kHz, pure rate: 9.91 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.08150691102788), np.float64(73.60239928552228), np.float64(52.35424481329989)):
#     Total rate = 35.37 kHz, pure rate: 10.38 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(39.345440886513025), np.float64(73.35584233394206), np.float64(54.23058783385744)):
#     Total rate = 24.60 kHz, pure rate: 5.70 kHz
#     Total eff: 95.26%, pure eff: 3.45%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.283267167820924), np.float64(75.14303499197082), np.float64(54.14077157291267)):
#     Total rate = 33.57 kHz, pure rate: 9.22 kHz
#     Total eff: 95.75%, pure eff: 3.94%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.620921541164435), np.float64(76.5953055177915), np.float64(53.649051871926766)):
#     Total rate = 36.06 kHz, pure rate: 10.24 kHz
#     Total eff: 95.87%, pure eff: 4.06%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.77487773851128), np.float64(75.1329049399138), np.float64(56.31130175823081)):
#     Total rate = 34.65 kHz, pure rate: 9.44 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.01519650472434), np.float64(78.32043787636339), np.float64(54.7395793519253)):
#     Total rate = 33.82 kHz, pure rate: 9.05 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.516183434825074), np.float64(76.84578219984382), np.float64(48.15009447962982)):
#     Total rate = 34.21 kHz, pure rate: 9.83 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.27470136125635), np.float64(78.95046654457381), np.float64(51.39324338730711)):
#     Total rate = 34.12 kHz, pure rate: 9.41 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.10009687279091), np.float64(74.4210821418483), np.float64(56.8475763771322)):
#     Total rate = 33.36 kHz, pure rate: 8.97 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.33964283718783), np.float64(82.89606672609867), np.float64(50.30261575034136)):
#     Total rate = 36.57 kHz, pure rate: 9.99 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.92764773846321), np.float64(79.81267757968068), np.float64(55.18866546540163)):
#     Total rate = 33.63 kHz, pure rate: 8.78 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.1054945665401), np.float64(79.40210542981494), np.float64(53.272525605531115)):
#     Total rate = 33.80 kHz, pure rate: 9.16 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.960525153518944), np.float64(83.98261904913318), np.float64(54.199281788629)):
#     Total rate = 32.85 kHz, pure rate: 8.13 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.22638248186865), np.float64(78.37219614878569), np.float64(50.670876123526085)):
#     Total rate = 34.49 kHz, pure rate: 9.68 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.13530664123871), np.float64(75.7703815741396), np.float64(55.9342083617461)):
#     Total rate = 33.33 kHz, pure rate: 9.02 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.42447932701526), np.float64(74.77919895342717), np.float64(50.42060732356017)):
#     Total rate = 34.38 kHz, pure rate: 9.96 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.10931177728336), np.float64(79.8823333533381), np.float64(51.13812478980601)):
#     Total rate = 34.55 kHz, pure rate: 9.63 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# differential_evolution step 33: f(x)= -0.04064039408866993
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.16692636066012), np.float64(77.12122098075042), np.float64(48.05289990512676)):
#     Total rate = 35.49 kHz, pure rate: 10.36 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.34040882576065), np.float64(79.42225256525066), np.float64(50.52788792230954)):
#     Total rate = 33.88 kHz, pure rate: 9.33 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.20178687260651), np.float64(74.56945485040532), np.float64(52.22483600992122)):
#     Total rate = 34.74 kHz, pure rate: 10.05 kHz
#     Total eff: 95.81%, pure eff: 4.00%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.98534016675317), np.float64(77.23105104370188), np.float64(50.96861458953892)):
#     Total rate = 35.68 kHz, pure rate: 10.29 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(33.129187129903855), np.float64(73.24015038069001), np.float64(52.974550728741015)):
#     Total rate = 48.57 kHz, pure rate: 16.47 kHz
#     Total eff: 96.06%, pure eff: 4.25%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.237702948799814), np.float64(75.18042607793873), np.float64(52.1378263735074)):
#     Total rate = 34.52 kHz, pure rate: 9.86 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.19409364980619), np.float64(80.11857421044607), np.float64(52.53596273685881)):
#     Total rate = 37.23 kHz, pure rate: 10.52 kHz
#     Total eff: 95.75%, pure eff: 3.94%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.932211062816705), np.float64(74.44040095912604), np.float64(55.53373377753298)):
#     Total rate = 34.37 kHz, pure rate: 9.47 kHz
#     Total eff: 95.87%, pure eff: 4.06%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.29811031015052), np.float64(75.78817935250329), np.float64(50.866354231205115)):
#     Total rate = 34.79 kHz, pure rate: 10.07 kHz
#     Total eff: 95.75%, pure eff: 3.94%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.282784889586836), np.float64(72.0685172973109), np.float64(51.52688875468012)):
#     Total rate = 31.67 kHz, pure rate: 8.85 kHz
#     Total eff: 95.57%, pure eff: 3.76%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.852736899848594), np.float64(82.72532949405525), np.float64(57.63931648620868)):
#     Total rate = 32.42 kHz, pure rate: 7.75 kHz
#     Total eff: 95.69%, pure eff: 3.88%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.164090157470106), np.float64(80.18952449158608), np.float64(48.58731919351478)):
#     Total rate = 34.77 kHz, pure rate: 9.74 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.024932479273744), np.float64(83.58848507019437), np.float64(50.18015189142632)):
#     Total rate = 37.56 kHz, pure rate: 10.33 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.042036004959506), np.float64(77.62541979190944), np.float64(55.58588837056095)):
#     Total rate = 33.50 kHz, pure rate: 8.89 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.61415527831285), np.float64(73.78517732178075), np.float64(45.78965183213841)):
#     Total rate = 28.32 kHz, pure rate: 7.53 kHz
#     Total eff: 95.38%, pure eff: 3.57%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.945374187294945), np.float64(75.12968554404537), np.float64(56.05169873199122)):
#     Total rate = 34.02 kHz, pure rate: 9.19 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.9992005526107), np.float64(78.01179748935695), np.float64(51.973308864566874)):
#     Total rate = 35.05 kHz, pure rate: 9.89 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.28539113790113), np.float64(76.04863281360804), np.float64(51.52030341828869)):
#     Total rate = 34.48 kHz, pure rate: 9.85 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(37.1904554648055), np.float64(71.72654505844886), np.float64(53.28701601410492)):
#     Total rate = 31.47 kHz, pure rate: 8.60 kHz
#     Total eff: 95.63%, pure eff: 3.82%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.105369873034796), np.float64(77.30768434943704), np.float64(50.66629082177703)):
#     Total rate = 35.09 kHz, pure rate: 10.08 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.24722856809647), np.float64(78.54820635827477), np.float64(54.28814752931589)):
#     Total rate = 33.03 kHz, pure rate: 8.72 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.12417961679102), np.float64(82.71996384464884), np.float64(51.63989108299447)):
#     Total rate = 33.38 kHz, pure rate: 8.67 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.13025253373129), np.float64(76.5668053558814), np.float64(55.247855795294726)):
#     Total rate = 33.47 kHz, pure rate: 9.08 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.52840992060309), np.float64(73.14201910761689), np.float64(54.018046379613054)):
#     Total rate = 33.02 kHz, pure rate: 9.21 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.232051720446925), np.float64(78.96056108031371), np.float64(50.77052955600138)):
#     Total rate = 34.30 kHz, pure rate: 9.52 kHz
#     Total eff: 95.69%, pure eff: 3.88%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.01519650472434), np.float64(76.39187219563694), np.float64(54.76522736241333)):
#     Total rate = 34.18 kHz, pure rate: 9.39 kHz
#     Total eff: 95.87%, pure eff: 4.06%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.13346267136948), np.float64(79.89040790854442), np.float64(51.93670058690213)):
#     Total rate = 34.07 kHz, pure rate: 9.32 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.23554413788928), np.float64(78.27352167555468), np.float64(52.15233350177761)):
#     Total rate = 33.93 kHz, pure rate: 9.35 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.868978577193786), np.float64(78.47258135211067), np.float64(54.486547255966364)):
#     Total rate = 34.38 kHz, pure rate: 9.30 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.04797577917566), np.float64(75.63192733297188), np.float64(55.39804442910207)):
#     Total rate = 34.02 kHz, pure rate: 9.38 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.33964283718783), np.float64(76.42577291000592), np.float64(57.10796147058582)):
#     Total rate = 35.74 kHz, pure rate: 9.75 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.1054945665401), np.float64(75.76111203950886), np.float64(53.272525605531115)):
#     Total rate = 34.51 kHz, pure rate: 9.82 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.89623712930338), np.float64(76.5953055177915), np.float64(54.752402513562934)):
#     Total rate = 34.49 kHz, pure rate: 9.47 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.117789302668555), np.float64(79.4047461541043), np.float64(55.39100522522348)):
#     Total rate = 33.00 kHz, pure rate: 8.64 kHz
#     Total eff: 95.81%, pure eff: 4.00%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.0975329124205), np.float64(77.30655881473197), np.float64(51.62820336593354)):
#     Total rate = 34.77 kHz, pure rate: 9.88 kHz
#     Total eff: 95.87%, pure eff: 4.06%L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(38.467932114749885), np.float64(79.0370189246842), np.float64(57.222979673421605)):
#     Total rate = 26.11 kHz, pure rate: 5.82 kHz
#     Total eff: 95.26%, pure eff: 3.45%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(35.95449927077286), np.float64(76.17195048405094), np.float64(52.47116831380567)):
#     Total rate = 35.38 kHz, pure rate: 10.18 kHz
#     Total eff: 95.87%, pure eff: 4.06%
#
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.1181844884538), np.float64(74.73041605636932), np.float64(52.78244634744464)):
#     Total rate = 34.84 kHz, pure rate: 10.08 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.161309202027624), np.float64(76.15891848813152), np.float64(54.199281788629)):
#     Total rate = 33.83 kHz, pure rate: 9.35 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.15037676835609), np.float64(75.03742671603982), np.float64(53.21524208438155)):
#     Total rate = 34.41 kHz, pure rate: 9.71 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.15298958464699), np.float64(77.33005780825366), np.float64(50.99347923701125)):
#     Total rate = 34.84 kHz, pure rate: 9.89 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.28548682302315), np.float64(76.12067253355781), np.float64(53.586749675134485)):
#     Total rate = 33.71 kHz, pure rate: 9.30 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.05058219586605), np.float64(75.26602362455027), np.float64(51.068230009983964)):
#     Total rate = 35.76 kHz, pure rate: 10.55 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.02033167042586), np.float64(75.7703815741396), np.float64(52.81278033704923)):
#     Total rate = 35.09 kHz, pure rate: 10.07 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.376393178870075), np.float64(75.18339197325717), np.float64(50.537862241453304)):
#     Total rate = 34.57 kHz, pure rate: 10.00 kHz
#     Total eff: 95.75%, pure eff: 3.94%
# differential_evolution step 34: f(x)= -0.04064039408866993
# Polishing solution with 'L-BFGS-B'
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.16692636066012), np.float64(77.12122098075042), np.float64(51.66249044127331)):
#     Total rate = 34.58 kHz, pure rate: 9.77 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.16692637066012), np.float64(77.12122098075042), np.float64(51.66249044127331)):
#     Total rate = 34.58 kHz, pure rate: 9.77 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.16692636066012), np.float64(77.12122099075042), np.float64(51.66249044127331)):
#     Total rate = 34.58 kHz, pure rate: 9.77 kHz
#     Total eff: 95.87%, pure eff: 4.06%
# L1_DoublePFJet8_Sum_Mass_dEtaMax(np.float64(36.16692636066012), np.float64(77.12122098075042), np.float64(51.662490451273314)):
#     Total rate = 34.58 kHz, pure rate: 9.77 kHz
#     Total eff: 95.87%, pure eff: 4.06%
#              message: Optimization terminated successfully.
#              success: True
#                  fun: -0.04064039408866993
#                    x: [ 3.617e+01  7.712e+01  5.166e+01]
#                  nit: 34
#                 nfev: 1579
#           population: [[ 3.617e+01  7.712e+01  5.166e+01]
#                        [ 3.595e+01  7.513e+01  5.605e+01]
#                        ...
#                        [ 3.609e+01  7.895e+01  5.042e+01]
#                        [ 3.611e+01  7.988e+01  5.114e+01]]
#  population_energies: [-4.064e-02 -4.064e-02 ... -4.002e-02 -4.002e-02]

# %%
# # L1_SinglePFJet8_Mass
# bounds = ((0, 70), (30, 160), (20, 150))
# L1_SinglePFJet8_Mass_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_Emyr_Mass,), workers=-1, disp=True)
# L1_SinglePFJet8_Mass_Opti
# Out:
# /eos/home-l/lroberts/Phase2-L1MenuTools/data/.env/lib64/python3.9/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# L1_DoublePFJet8_Emyr_Mass(np.float64(31.765168145532265), np.float64(85.00816952131274), np.float64(86.53171197982033)):
#     Total rate = 42.33 kHz, pure rate: 4.49 kHz
#     Total eff: 97.32%, pure eff: 1.76%
# L1_DoublePFJet8_Emyr_Mass(np.float64(47.99552950017241), np.float64(158.54011021329256), np.float64(69.50899837216319)):
#     Total rate = 9.24 kHz, pure rate: 0.08 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(61.586356522247456), np.float64(65.68111219117782), np.float64(133.5123199926599)):
#     Total rate = 3.90 kHz, pure rate: 0.03 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.89564631180885), np.float64(74.5341979891144), np.float64(30.955056678016653)):
#     Total rate = 226.08 kHz, pure rate: 126.66 kHz
#     Total eff: 99.04%, pure eff: 3.48%
# L1_DoublePFJet8_Emyr_Mass(np.float64(17.71719436244662), np.float64(100.47759436320868), np.float64(61.920865381648795)):
#     Total rate = 117.91 kHz, pure rate: 27.99 kHz
#     Total eff: 98.43%, pure eff: 2.87%
# L1_DoublePFJet8_Emyr_Mass(np.float64(10.600220067079949), np.float64(136.5041442530137), np.float64(65.82458619798363)):
#     Total rate = 48.53 kHz, pure rate: 2.19 kHz
#     Total eff: 96.41%, pure eff: 0.84%L1_DoublePFJet8_Emyr_Mass(np.float64(50.795692670321614), np.float64(118.39616792788392), np.float64(57.65692134546245)):
#     Total rate = 12.62 kHz, pure rate: 0.97 kHz
#     Total eff: 96.79%, pure eff: 1.22%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(8.024630218155519), np.float64(147.37539779585387), np.float64(82.04899988599311)):
#     Total rate = 32.33 kHz, pure rate: 0.55 kHz
#     Total eff: 95.95%, pure eff: 0.38%
# L1_DoublePFJet8_Emyr_Mass(np.float64(32.927667964559035), np.float64(150.97884803669595), np.float64(142.25790953160296)):
#     Total rate = 9.80 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.203131125114574), np.float64(37.30208463448089), np.float64(85.12211181910156)):
#     Total rate = 25.13 kHz, pure rate: 2.71 kHz
#     Total eff: 97.02%, pure eff: 1.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(16.021189742999724), np.float64(91.27421871357011), np.float64(101.3518210397506)):
#     Total rate = 43.09 kHz, pure rate: 2.13 kHz
#     Total eff: 96.48%, pure eff: 0.92%
# L1_DoublePFJet8_Emyr_Mass(np.float64(58.01613598654935), np.float64(48.385891265498344), np.float64(113.59192643292269)):
#     Total rate = 5.95 kHz, pure rate: 0.11 kHz
#     Total eff: 95.87%, pure eff: 0.31%L1_DoublePFJet8_Emyr_Mass(np.float64(12.673153609141167), np.float64(50.55909465967632), np.float64(147.81696386186866)):
#     Total rate = 10.98 kHz, pure rate: 0.00 kHz
#     Total eff: 95.60%, pure eff: 0.04%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(28.035168831363833), np.float64(133.78415951198605), np.float64(26.067346716752226)):
#     Total rate = 42.60 kHz, pure rate: 3.29 kHz
#     Total eff: 96.71%, pure eff: 1.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.433959221009474), np.float64(125.08935102675763), np.float64(145.10029724661206)):
#     Total rate = 8.75 kHz, pure rate: 0.00 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(63.967608821618285), np.float64(144.86102082029802), np.float64(111.99685816841352)):
#     Total rate = 3.77 kHz, pure rate: 0.05 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(45.76062128397997), np.float64(152.88628883513948), np.float64(22.48664986139344)):
#     Total rate = 11.66 kHz, pure rate: 0.25 kHz
#     Total eff: 96.02%, pure eff: 0.46%
# L1_DoublePFJet8_Emyr_Mass(np.float64(67.74731861344665), np.float64(113.95770834478853), np.float64(104.23999565166771)):
#     Total rate = 3.21 kHz, pure rate: 0.06 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(0.13360468889404586), np.float64(57.98123999705705), np.float64(42.964342219564315)):
#     Total rate = 901.27 kHz, pure rate: 669.26 kHz
#     Total eff: 99.73%, pure eff: 4.17%
# L1_DoublePFJet8_Emyr_Mass(np.float64(6.179093459384486), np.float64(53.61055966603175), np.float64(34.97828058388194)):
#     Total rate = 1523.86 kHz, pure rate: 1253.65 kHz
#     Total eff: 99.85%, pure eff: 4.28%
# L1_DoublePFJet8_Emyr_Mass(np.float64(43.13040096761099), np.float64(64.23774188779834), np.float64(99.05901004639816)):
#     Total rate = 16.13 kHz, pure rate: 0.85 kHz
#     Total eff: 96.37%, pure eff: 0.80%L1_DoublePFJet8_Emyr_Mass(np.float64(22.029813505744862), np.float64(81.43831702164094), np.float64(108.36935266622913)):
#     Total rate = 31.36 kHz, pure rate: 1.02 kHz
#     Total eff: 96.29%, pure eff: 0.73%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(14.149034343242537), np.float64(88.79553280804342), np.float64(73.80505974781627)):
#     Total rate = 123.89 kHz, pure rate: 26.18 kHz
#     Total eff: 98.13%, pure eff: 2.56%
# L1_DoublePFJet8_Emyr_Mass(np.float64(7.701467669066229), np.float64(120.96019499790371), np.float64(49.611929129873985)):
#     Total rate = 87.72 kHz, pure rate: 12.24 kHz
#     Total eff: 97.52%, pure eff: 1.95%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.97073009408049), np.float64(109.7062202806086), np.float64(75.60684849216983)):
#     Total rate = 24.13 kHz, pure rate: 2.44 kHz
#     Total eff: 96.98%, pure eff: 1.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(63.69277622947652), np.float64(60.57264867918004), np.float64(32.47497737018013)):
#     Total rate = 5.03 kHz, pure rate: 0.30 kHz
#     Total eff: 96.10%, pure eff: 0.54%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.38303243608262), np.float64(35.06726771940402), np.float64(138.85299166281033)):
#     Total rate = 9.19 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(3.3572389514185446), np.float64(39.3514871053354), np.float64(129.03015703002325)):
#     Total rate = 19.05 kHz, pure rate: 0.08 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(69.40687475636074), np.float64(45.25496398689599), np.float64(54.356069658677384)):
#     Total rate = 3.26 kHz, pure rate: 0.11 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(43.7252321668922), np.float64(156.50948094165977), np.float64(44.20068907588343)):
#     Total rate = 12.29 kHz, pure rate: 0.17 kHz
#     Total eff: 95.91%, pure eff: 0.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(49.44798360201592), np.float64(43.46214508056173), np.float64(47.938395580735076)):
#     Total rate = 15.48 kHz, pure rate: 2.18 kHz
#     Total eff: 97.25%, pure eff: 1.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(57.52572052730633), np.float64(32.726870455780755), np.float64(90.10867940972558)):
#     Total rate = 7.44 kHz, pure rate: 0.38 kHz
#     Total eff: 96.25%, pure eff: 0.69%
# L1_DoublePFJet8_Emyr_Mass(np.float64(30.75986607554125), np.float64(130.3468727823919), np.float64(97.03999580728303)):
#     Total rate = 25.86 kHz, pure rate: 0.86 kHz
#     Total eff: 96.10%, pure eff: 0.54%
# L1_DoublePFJet8_Emyr_Mass(np.float64(52.20297010110211), np.float64(106.7643271237636), np.float64(24.706974839694404)):
#     Total rate = 12.31 kHz, pure rate: 1.05 kHz
#     Total eff: 96.90%, pure eff: 1.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(24.837533152275423), np.float64(112.23134251214641), np.float64(66.70321846935245)):
#     Total rate = 66.52 kHz, pure rate: 9.22 kHz
#     Total eff: 97.55%, pure eff: 1.99%
# L1_DoublePFJet8_Emyr_Mass(np.float64(55.61855764983571), np.float64(95.94144124560718), np.float64(130.1230417006081)):
#     Total rate = 5.50 kHz, pure rate: 0.06 kHz
#     Total eff: 95.72%, pure eff: 0.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(65.39535699849796), np.float64(104.101364105084), np.float64(55.78955915583074)):
#     Total rate = 4.32 kHz, pure rate: 0.19 kHz
#     Total eff: 96.02%, pure eff: 0.46%
# L1_DoublePFJet8_Emyr_Mass(np.float64(27.054800561586987), np.float64(82.45214542274981), np.float64(123.18026079578509)):
#     Total rate = 18.72 kHz, pure rate: 0.28 kHz
#     Total eff: 95.80%, pure eff: 0.23%
# L1_DoublePFJet8_Emyr_Mass(np.float64(53.45821440333894), np.float64(138.77898294977723), np.float64(119.45408741990704)):
#     Total rate = 7.05 kHz, pure rate: 0.09 kHz
#     Total eff: 95.72%, pure eff: 0.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.362188878451136), np.float64(71.7886659557486), np.float64(125.12596619824421)):
#     Total rate = 19.73 kHz, pure rate: 0.19 kHz
#     Total eff: 95.80%, pure eff: 0.23%
# L1_DoublePFJet8_Emyr_Mass(np.float64(1.6250416251990814), np.float64(141.79469565577125), np.float64(37.58814284721283)):
#     Total rate = 48.52 kHz, pure rate: 2.04 kHz
#     Total eff: 96.33%, pure eff: 0.76%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.87410384233277), np.float64(77.65192280769422), np.float64(94.76888796450399)):
#     Total rate = 25.32 kHz, pure rate: 1.74 kHz
#     Total eff: 96.71%, pure eff: 1.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(59.82978178730467), np.float64(97.30374158547149), np.float64(78.21286738565945)):
#     Total rate = 6.58 kHz, pure rate: 0.38 kHz
#     Total eff: 96.29%, pure eff: 0.73%
# L1_DoublePFJet8_Emyr_Mass(np.float64(12.045151023384754), np.float64(126.32547411857611), np.float64(137.65907457133432)):
#     Total rate = 14.69 kHz, pure rate: 0.03 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(21.399628944498474), np.float64(67.60165163124785), np.float64(118.1453224491325)):
#     Total rate = 23.84 kHz, pure rate: 0.50 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(18.30083765707452), np.float64(37.30208463448089), np.float64(68.89419675305734)):
#     Total rate = 162.26 kHz, pure rate: 54.66 kHz
#     Total eff: 98.55%, pure eff: 2.98%
# L1_DoublePFJet8_Emyr_Mass(np.float64(13.526242493336024), np.float64(125.08935102675763), np.float64(92.62468757539762)):
#     Total rate = 44.15 kHz, pure rate: 1.93 kHz
#     Total eff: 96.37%, pure eff: 0.80%
# L1_DoublePFJet8_Emyr_Mass(np.float64(47.99552950017241), np.float64(93.82907449259814), np.float64(47.65436309211447)):
#     Total rate = 17.64 kHz, pure rate: 2.41 kHz
#     Total eff: 97.29%, pure eff: 1.72%
# L1_DoublePFJet8_Emyr_Mass(np.float64(7.255039077767641), np.float64(104.63948094578897), np.float64(55.31594817115817)):
#     Total rate = 133.86 kHz, pure rate: 33.24 kHz
#     Total eff: 98.55%, pure eff: 2.98%L1_DoublePFJet8_Emyr_Mass(np.float64(8.024630218155519), np.float64(94.7965589472), np.float64(82.04899988599311)):
#     Total rate = 93.53 kHz, pure rate: 13.26 kHz
#     Total eff: 97.52%, pure eff: 1.95%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.89564631180885), np.float64(81.57823681321273), np.float64(81.40520928679575)):
#     Total rate = 69.89 kHz, pure rate: 10.90 kHz
#     Total eff: 97.55%, pure eff: 1.99%L1_DoublePFJet8_Emyr_Mass(np.float64(0.273728972940134), np.float64(105.20518811054323), np.float64(53.99137300205582)):
#     Total rate = 136.74 kHz, pure rate: 34.49 kHz
#     Total eff: 98.51%, pure eff: 2.94%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(31.37463200672514), np.float64(128.82708374341593), np.float64(82.96411676752703)):
#     Total rate = 31.33 kHz, pure rate: 1.50 kHz
#     Total eff: 96.41%, pure eff: 0.84%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.66228060688012), np.float64(108.0381162433247), np.float64(60.672497915214905)):
#     Total rate = 32.16 kHz, pure rate: 4.68 kHz
#     Total eff: 97.59%, pure eff: 2.03%L1_DoublePFJet8_Emyr_Mass(np.float64(45.52996396346305), np.float64(141.65275113989358), np.float64(103.30354663913499)):
#     Total rate = 10.85 kHz, pure rate: 0.17 kHz
#     Total eff: 95.83%, pure eff: 0.27%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(43.15471112236465), np.float64(50.55909465967632), np.float64(72.72810385960408)):
#     Total rate = 23.84 kHz, pure rate: 3.66 kHz
#     Total eff: 97.32%, pure eff: 1.76%
# L1_DoublePFJet8_Emyr_Mass(np.float64(4.2605975420764715), np.float64(86.06681215130827), np.float64(42.964342219564315)):
#     Total rate = 308.62 kHz, pure rate: 148.16 kHz
#     Total eff: 99.35%, pure eff: 3.78%L1_DoublePFJet8_Emyr_Mass(np.float64(51.00628034263863), np.float64(60.41391210921121), np.float64(83.21480094248261)):
#     Total rate = 12.06 kHz, pure rate: 1.10 kHz
#     Total eff: 96.71%, pure eff: 1.15%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(9.620482507098483), np.float64(129.5282279205652), np.float64(76.55854001674737)):
#     Total rate = 52.42 kHz, pure rate: 2.69 kHz
#     Total eff: 96.52%, pure eff: 0.96%L1_DoublePFJet8_Emyr_Mass(np.float64(43.656257479473396), np.float64(129.09454066620492), np.float64(133.5123199926599)):
#     Total rate = 8.61 kHz, pure rate: 0.05 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(17.71719436244662), np.float64(127.77087861019669), np.float64(39.61925429913737)):
#     Total rate = 66.45 kHz, pure rate: 6.95 kHz
#     Total eff: 97.13%, pure eff: 1.57%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(47.29925560825397), np.float64(85.00816952131274), np.float64(86.53171197982033)):
#     Total rate = 15.50 kHz, pure rate: 1.41 kHz
#     Total eff: 96.71%, pure eff: 1.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(6.179093459384486), np.float64(117.26728043905588), np.float64(106.05774550172502)):
#     Total rate = 36.98 kHz, pure rate: 1.22 kHz
#     Total eff: 96.29%, pure eff: 0.73%L1_DoublePFJet8_Emyr_Mass(np.float64(33.13481244608441), np.float64(126.79816813423258), np.float64(105.1207932519648)):
#     Total rate = 21.40 kHz, pure rate: 0.61 kHz
#     Total eff: 96.02%, pure eff: 0.46%
# L1_DoublePFJet8_Emyr_Mass(np.float64(14.149034343242537), np.float64(88.79553280804342), np.float64(84.63775504343235)):
#     Total rate = 84.78 kHz, pure rate: 11.41 kHz
#     Total eff: 97.52%, pure eff: 1.95%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(29.7372791262999), np.float64(145.07619894265264), np.float64(55.65534245978891)):
#     Total rate = 28.17 kHz, pure rate: 0.85 kHz
#     Total eff: 96.22%, pure eff: 0.65%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.96196939310781), np.float64(81.43831702164094), np.float64(108.36935266622913)):
#     Total rate = 15.58 kHz, pure rate: 0.49 kHz
#     Total eff: 96.06%, pure eff: 0.50%
# L1_DoublePFJet8_Emyr_Mass(np.float64(3.1109770307462696), np.float64(152.88628883513948), np.float64(22.48664986139344)):
#     Total rate = 35.99 kHz, pure rate: 0.67 kHz
#     Total eff: 96.10%, pure eff: 0.54%
# L1_DoublePFJet8_Emyr_Mass(np.float64(23.70667151102187), np.float64(134.65524797133745), np.float64(61.118406348455636)):
#     Total rate = 43.12 kHz, pure rate: 2.36 kHz
#     Total eff: 96.56%, pure eff: 0.99%
# L1_DoublePFJet8_Emyr_Mass(np.float64(43.34705984473008), np.float64(152.07405364522117), np.float64(99.05901004639816)):
#     Total rate = 10.94 kHz, pure rate: 0.11 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(69.40687475636074), np.float64(131.72100874173103), np.float64(38.348722035486446)):
#     Total rate = 3.15 kHz, pure rate: 0.05 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(11.20127612652061), np.float64(57.00091343182088), np.float64(138.85299166281033)):
#     Total rate = 14.12 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(20.617926423311044), np.float64(69.93664311506488), np.float64(26.663600257480837)):
#     Total rate = 452.61 kHz, pure rate: 304.28 kHz
#     Total eff: 99.39%, pure eff: 3.82%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.446059809061744), np.float64(146.76460934439402), np.float64(95.8738696269499)):
#     Total rate = 23.56 kHz, pure rate: 0.23 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.18901046793239), np.float64(139.82576971525583), np.float64(49.611929129873985)):
#     Total rate = 43.84 kHz, pure rate: 2.10 kHz
#     Total eff: 96.48%, pure eff: 0.92%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.941955855577525), np.float64(48.385891265498344), np.float64(113.59192643292269)):
#     Total rate = 14.20 kHz, pure rate: 0.36 kHz
#     Total eff: 95.91%, pure eff: 0.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(20.810728852716025), np.float64(60.57264867918004), np.float64(67.72172495362939)):
#     Total rate = 154.90 kHz, pure rate: 55.35 kHz
#     Total eff: 98.55%, pure eff: 2.98%L1_DoublePFJet8_Emyr_Mass(np.float64(53.45821440333894), np.float64(109.33625599558454), np.float64(118.03263079359101)):
#     Total rate = 7.39 kHz, pure rate: 0.09 kHz
#     Total eff: 95.76%, pure eff: 0.19%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(57.52572052730633), np.float64(115.91077161566568), np.float64(111.54854904348511)):
#     Total rate = 6.20 kHz, pure rate: 0.11 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(17.61984728754324), np.float64(138.76388216995161), np.float64(106.36449104494554)):
#     Total rate = 25.97 kHz, pure rate: 0.28 kHz
#     Total eff: 95.95%, pure eff: 0.38%
# L1_DoublePFJet8_Emyr_Mass(np.float64(27.62380070152775), np.float64(73.4754087513586), np.float64(100.93864799694269)):
#     Total rate = 33.86 kHz, pure rate: 1.53 kHz
#     Total eff: 96.44%, pure eff: 0.88%
# L1_DoublePFJet8_Emyr_Mass(np.float64(23.482966915943855), np.float64(73.16054738193544), np.float64(99.8102894798919)):
#     Total rate = 39.58 kHz, pure rate: 2.16 kHz
#     Total eff: 96.52%, pure eff: 0.96%
# L1_DoublePFJet8_Emyr_Mass(np.float64(55.30561182227021), np.float64(95.94144124560718), np.float64(87.96879408633812)):
#     Total rate = 8.80 kHz, pure rate: 0.56 kHz
#     Total eff: 96.41%, pure eff: 0.84%
# L1_DoublePFJet8_Emyr_Mass(np.float64(55.31837251503654), np.float64(126.01395001512087), np.float64(69.04946884994018)):
#     Total rate = 8.77 kHz, pure rate: 0.41 kHz
#     Total eff: 96.22%, pure eff: 0.65%L1_DoublePFJet8_Emyr_Mass(np.float64(29.566552423925515), np.float64(101.19021934327967), np.float64(77.46351358182244)):
#     Total rate = 53.47 kHz, pure rate: 6.79 kHz
#     Total eff: 97.55%, pure eff: 1.99%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(12.045151023384754), np.float64(75.44428696367476), np.float64(55.98388633229562)):
#     Total rate = 298.21 kHz, pure rate: 146.82 kHz
#     Total eff: 99.39%, pure eff: 3.82%
# L1_DoublePFJet8_Emyr_Mass(np.float64(41.044673684620065), np.float64(94.39888919709966), np.float64(125.12596619824421)):
#     Total rate = 11.19 kHz, pure rate: 0.13 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(5.858633960589287), np.float64(97.30374158547149), np.float64(64.08742997683635)):
#     Total rate = 142.25 kHz, pure rate: 35.35 kHz
#     Total eff: 98.55%, pure eff: 2.98%
# L1_DoublePFJet8_Emyr_Mass(np.float64(21.399628944498474), np.float64(144.80988811879723), np.float64(34.960304200019934)):
#     Total rate = 37.43 kHz, pure rate: 1.19 kHz
#     Total eff: 96.25%, pure eff: 0.69%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.905262146843675), np.float64(141.79469565577125), np.float64(98.00144133446526)):
#     Total rate = 14.20 kHz, pure rate: 0.22 kHz
#     Total eff: 95.91%, pure eff: 0.34%
# differential_evolution step 1: f(x)= -0.020259938837920433
# L1_DoublePFJet8_Emyr_Mass(np.float64(59.673455902426895), np.float64(97.7349423343552), np.float64(70.03955440565349)):
#     Total rate = 6.84 kHz, pure rate: 0.42 kHz
#     Total eff: 96.29%, pure eff: 0.73%
# L1_DoublePFJet8_Emyr_Mass(np.float64(29.64973684623671), np.float64(145.7719896623712), np.float64(50.139919251291474)):
#     Total rate = 28.20 kHz, pure rate: 0.94 kHz
#     Total eff: 96.22%, pure eff: 0.65%
# L1_DoublePFJet8_Emyr_Mass(np.float64(1.6610678450037213), np.float64(34.84060251931764), np.float64(122.04772811437064)):
#     Total rate = 23.01 kHz, pure rate: 0.38 kHz
#     Total eff: 95.80%, pure eff: 0.23%L1_DoublePFJet8_Emyr_Mass(np.float64(17.71719436244662), np.float64(140.73944200317698), np.float64(111.9810455475475)):
#     Total rate = 23.14 kHz, pure rate: 0.17 kHz
#     Total eff: 95.80%, pure eff: 0.23%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(7.7564906215948), np.float64(152.24426753306867), np.float64(110.05755460337707)):
#     Total rate = 21.21 kHz, pure rate: 0.16 kHz
#     Total eff: 95.76%, pure eff: 0.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(13.78908805743206), np.float64(157.66511829491182), np.float64(119.88734904660407)):
#     Total rate = 17.11 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.66228060688012), np.float64(106.41330385640816), np.float64(26.519123487204332)):
#     Total rate = 37.03 kHz, pure rate: 7.25 kHz
#     Total eff: 97.74%, pure eff: 2.18%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.36862946334746), np.float64(135.8755198485327), np.float64(38.474459630732284)):
#     Total rate = 20.89 kHz, pure rate: 1.24 kHz
#     Total eff: 96.48%, pure eff: 0.92%L1_DoublePFJet8_Emyr_Mass(np.float64(21.4110353623094), np.float64(112.69425049910875), np.float64(97.05895940364368)):
#     Total rate = 42.52 kHz, pure rate: 2.40 kHz
#     Total eff: 96.60%, pure eff: 1.03%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(16.021189742999724), np.float64(119.92639103442907), np.float64(84.63900465470009)):
#     Total rate = 55.14 kHz, pure rate: 3.32 kHz
#     Total eff: 96.64%, pure eff: 1.07%L1_DoublePFJet8_Emyr_Mass(np.float64(25.89564631180885), np.float64(81.71366955814642), np.float64(81.40520928679575)):
#     Total rate = 69.89 kHz, pure rate: 10.90 kHz
#     Total eff: 97.55%, pure eff: 1.99%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.90154032884444), np.float64(147.37539779585387), np.float64(86.49046241007424)):
#     Total rate = 19.13 kHz, pure rate: 0.36 kHz
#     Total eff: 95.95%, pure eff: 0.38%
# L1_DoublePFJet8_Emyr_Mass(np.float64(53.16160341905497), np.float64(96.27730302516346), np.float64(85.12211181910156)):
#     Total rate = 10.49 kHz, pure rate: 0.83 kHz
#     Total eff: 96.56%, pure eff: 0.99%
# L1_DoublePFJet8_Emyr_Mass(np.float64(7.109810741729685), np.float64(145.5923643100609), np.float64(102.26805918162657)):
#     Total rate = 26.26 kHz, pure rate: 0.25 kHz
#     Total eff: 95.87%, pure eff: 0.31%L1_DoublePFJet8_Emyr_Mass(np.float64(2.6395473046967055), np.float64(115.5391507608782), np.float64(111.01065758950385)):
#     Total rate = 32.52 kHz, pure rate: 0.91 kHz
#     Total eff: 96.10%, pure eff: 0.54%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(20.8601542074731), np.float64(58.82946811024219), np.float64(42.964342219564315)):
#     Total rate = 430.52 kHz, pure rate: 289.30 kHz
#     Total eff: 99.35%, pure eff: 3.78%
# L1_DoublePFJet8_Emyr_Mass(np.float64(43.15471112236465), np.float64(147.57571927749723), np.float64(67.8723844309831)):
#     Total rate = 14.01 kHz, pure rate: 0.33 kHz
#     Total eff: 96.06%, pure eff: 0.50%
# L1_DoublePFJet8_Emyr_Mass(np.float64(50.85112468495954), np.float64(65.98943774992705), np.float64(78.3026190307863)):
#     Total rate = 12.45 kHz, pure rate: 1.21 kHz
#     Total eff: 96.75%, pure eff: 1.19%L1_DoublePFJet8_Emyr_Mass(np.float64(7.445523448341202), np.float64(63.37079018043215), np.float64(128.21565606018385)):
#     Total rate = 19.48 kHz, pure rate: 0.13 kHz
#     Total eff: 95.76%, pure eff: 0.19%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(3.1109770307462696), np.float64(115.90464734813858), np.float64(54.73216665079059)):
#     Total rate = 97.63 kHz, pure rate: 15.88 kHz
#     Total eff: 97.86%, pure eff: 2.29%
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.650692055427395), np.float64(111.42679304732212), np.float64(122.23485232299521)):
#     Total rate = 21.64 kHz, pure rate: 0.33 kHz
#     Total eff: 95.80%, pure eff: 0.23%
# L1_DoublePFJet8_Emyr_Mass(np.float64(44.932933330604314), np.float64(155.60100099182964), np.float64(96.49395236345211)):
#     Total rate = 10.13 kHz, pure rate: 0.09 kHz
#     Total eff: 95.68%, pure eff: 0.11%L1_DoublePFJet8_Emyr_Mass(np.float64(40.97073009408049), np.float64(150.89284524343145), np.float64(75.60684849216983)):
#     Total rate = 14.44 kHz, pure rate: 0.22 kHz
#     Total eff: 96.06%, pure eff: 0.50%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.18901046793239), np.float64(148.29491387404576), np.float64(88.67037928095309)):
#     Total rate = 27.37 kHz, pure rate: 0.33 kHz
#     Total eff: 95.91%, pure eff: 0.34%L1_DoublePFJet8_Emyr_Mass(np.float64(36.17929208806653), np.float64(134.65524797133745), np.float64(142.9620661333558)):
#     Total rate = 9.02 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.56780538887926), np.float64(135.72493674475274), np.float64(131.4698735934407)):
#     Total rate = 11.16 kHz, pure rate: 0.06 kHz
#     Total eff: 95.72%, pure eff: 0.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.668209618506317), np.float64(86.31489496822438), np.float64(138.85299166281033)):
#     Total rate = 12.82 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.566901962368924), np.float64(58.73688771767905), np.float64(56.80576443533594)):
#     Total rate = 77.14 kHz, pure rate: 28.70 kHz
#     Total eff: 98.51%, pure eff: 2.94%L1_DoublePFJet8_Emyr_Mass(np.float64(43.13040096761099), np.float64(64.23774188779834), np.float64(29.90206630314789)):
#     Total rate = 30.81 kHz, pure rate: 7.84 kHz
#     Total eff: 97.82%, pure eff: 2.26%
# L1_DoublePFJet8_Emyr_Mass(np.float64(62.548297543733106), np.float64(141.19438657840206), np.float64(97.03999580728303)):
#     Total rate = 4.46 kHz, pure rate: 0.06 kHz
#     Total eff: 95.83%, pure eff: 0.27%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(27.03670596182098), np.float64(139.64934687869504), np.float64(103.97109749448256)):
#     Total rate = 23.14 kHz, pure rate: 0.30 kHz
#     Total eff: 95.91%, pure eff: 0.34%L1_DoublePFJet8_Emyr_Mass(np.float64(17.29390968707869), np.float64(42.25330090449502), np.float64(106.50771427073931)):
#     Total rate = 35.38 kHz, pure rate: 1.22 kHz
#     Total eff: 96.37%, pure eff: 0.80%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.77215952208988), np.float64(96.07842298313552), np.float64(81.8892249824686)):
#     Total rate = 37.51 kHz, pure rate: 4.23 kHz
#     Total eff: 97.25%, pure eff: 1.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.73670467050496), np.float64(91.0951410178229), np.float64(87.96879408633812)):
#     Total rate = 28.04 kHz, pure rate: 2.71 kHz
#     Total eff: 97.06%, pure eff: 1.49%
# L1_DoublePFJet8_Emyr_Mass(np.float64(57.52572052730633), np.float64(92.33020212096099), np.float64(42.526254153061984)):
#     Total rate = 8.36 kHz, pure rate: 0.63 kHz
#     Total eff: 96.44%, pure eff: 0.88%
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.003197085625), np.float64(48.38717688888904), np.float64(133.22719282365475)):
#     Total rate = 16.28 kHz, pure rate: 0.05 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.1865502460073), np.float64(68.03150014295628), np.float64(83.85521084825622)):
#     Total rate = 39.20 kHz, pure rate: 4.76 kHz
#     Total eff: 97.32%, pure eff: 1.76%L1_DoublePFJet8_Emyr_Mass(np.float64(24.85974852300587), np.float64(58.33358701725645), np.float64(54.52626307661561)):
#     Total rate = 204.63 kHz, pure rate: 108.23 kHz
#     Total eff: 99.04%, pure eff: 3.48%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.18678535305383), np.float64(124.53927654974771), np.float64(65.7488746792334)):
#     Total rate = 27.65 kHz, pure rate: 2.35 kHz
#     Total eff: 96.71%, pure eff: 1.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(31.693952409995934), np.float64(89.77587585206503), np.float64(89.24746014731838)):
#     Total rate = 40.06 kHz, pure rate: 3.80 kHz
#     Total eff: 97.21%, pure eff: 1.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(3.7254492280300155), np.float64(147.1923204916214), np.float64(78.6054608071206)):
#     Total rate = 33.82 kHz, pure rate: 0.63 kHz
#     Total eff: 96.02%, pure eff: 0.46%
# L1_DoublePFJet8_Emyr_Mass(np.float64(18.865750237225715), np.float64(73.4754087513586), np.float64(100.93864799694269)):
#     Total rate = 42.41 kHz, pure rate: 2.13 kHz
#     Total eff: 96.48%, pure eff: 0.92%L1_DoublePFJet8_Emyr_Mass(np.float64(12.045151023384754), np.float64(116.19376041525814), np.float64(24.727226437016782)):
#     Total rate = 112.82 kHz, pure rate: 22.98 kHz
#     Total eff: 97.90%, pure eff: 2.33%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(52.81560601917207), np.float64(119.33184579893992), np.float64(34.960304200019934)):
#     Total rate = 11.29 kHz, pure rate: 0.81 kHz
#     Total eff: 96.60%, pure eff: 1.03%
# L1_DoublePFJet8_Emyr_Mass(np.float64(55.965556998743736), np.float64(111.75622642389393), np.float64(37.58814284721283)):
#     Total rate = 9.27 kHz, pure rate: 0.58 kHz
#     Total eff: 96.37%, pure eff: 0.80%
# differential_evolution step 2: f(x)= -0.02255351681957185
# L1_DoublePFJet8_Emyr_Mass(np.float64(45.00051673236422), np.float64(95.33125109141974), np.float64(58.40117042206468)):
#     Total rate = 21.68 kHz, pure rate: 3.05 kHz
#     Total eff: 97.48%, pure eff: 1.91%
# L1_DoublePFJet8_Emyr_Mass(np.float64(14.505148017622474), np.float64(147.37539779585387), np.float64(75.69446553050292)):
#     Total rate = 33.02 kHz, pure rate: 0.56 kHz
#     Total eff: 96.06%, pure eff: 0.50%
# L1_DoublePFJet8_Emyr_Mass(np.float64(52.846751007396186), np.float64(50.79792437644622), np.float64(24.754948089059)):
#     Total rate = 12.24 kHz, pure rate: 1.46 kHz
#     Total eff: 96.90%, pure eff: 1.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.13156376081391), np.float64(55.31543176501122), np.float64(84.63900465470009)):
#     Total rate = 27.27 kHz, pure rate: 3.10 kHz
#     Total eff: 97.06%, pure eff: 1.49%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.985395959734795), np.float64(81.79297603219507), np.float64(80.4288183795068)):
#     Total rate = 37.53 kHz, pure rate: 5.48 kHz
#     Total eff: 97.44%, pure eff: 1.87%L1_DoublePFJet8_Emyr_Mass(np.float64(44.86730507438812), np.float64(52.060049339034485), np.float64(27.98216039226528)):
#     Total rate = 25.72 kHz, pure rate: 5.73 kHz
#     Total eff: 97.52%, pure eff: 1.95%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(17.71719436244662), np.float64(47.09443354282593), np.float64(108.82738171109727)):
#     Total rate = 33.07 kHz, pure rate: 0.97 kHz
#     Total eff: 96.29%, pure eff: 0.73%
# L1_DoublePFJet8_Emyr_Mass(np.float64(51.00628034263863), np.float64(68.29149196491706), np.float64(94.25941466330181)):
#     Total rate = 10.76 kHz, pure rate: 0.64 kHz
#     Total eff: 96.44%, pure eff: 0.88%L1_DoublePFJet8_Emyr_Mass(np.float64(34.56079883428101), np.float64(37.30208463448089), np.float64(50.6332951479155)):
#     Total rate = 76.06 kHz, pure rate: 29.84 kHz
#     Total eff: 98.51%, pure eff: 2.94%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(13.526242493336024), np.float64(93.28059508477652), np.float64(81.88577381891378)):
#     Total rate = 91.34 kHz, pure rate: 13.10 kHz
#     Total eff: 97.52%, pure eff: 1.95%L1_DoublePFJet8_Emyr_Mass(np.float64(56.16647239171872), np.float64(32.57797068692553), np.float64(43.58609580430612)):
#     Total rate = 9.41 kHz, pure rate: 0.80 kHz
#     Total eff: 96.52%, pure eff: 0.96%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.89564631180885), np.float64(117.64513455631952), np.float64(126.87013744995645)):
#     Total rate = 17.93 kHz, pure rate: 0.14 kHz
#     Total eff: 95.80%, pure eff: 0.23%L1_DoublePFJet8_Emyr_Mass(np.float64(9.620482507098483), np.float64(65.7082508539347), np.float64(127.91249393653668)):
#     Total rate = 19.48 kHz, pure rate: 0.13 kHz
#     Total eff: 95.76%, pure eff: 0.19%
#
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(7.7564906215948), np.float64(60.33272119032214), np.float64(76.28491416295336)):
#     Total rate = 138.21 kHz, pure rate: 32.80 kHz
#     Total eff: 98.09%, pure eff: 2.52%L1_DoublePFJet8_Emyr_Mass(np.float64(52.63852799023339), np.float64(115.5391507608782), np.float64(53.50941664729361)):
#     Total rate = 11.37 kHz, pure rate: 0.89 kHz
#     Total eff: 96.75%, pure eff: 1.19%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(66.06621189345594), np.float64(45.51763312492429), np.float64(105.92553845647362)):
#     Total rate = 3.62 kHz, pure rate: 0.05 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(30.586995996847566), np.float64(65.98943774992705), np.float64(77.3347243553546)):
#     Total rate = 59.43 kHz, pure rate: 11.12 kHz
#     Total eff: 97.71%, pure eff: 2.14%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.18317558365409), np.float64(74.05222603807022), np.float64(28.144632904727942)):
#     Total rate = 59.04 kHz, pure rate: 21.31 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(53.88647966581083), np.float64(65.7082508539347), np.float64(36.95341123636701)):
#     Total rate = 11.27 kHz, pure rate: 1.27 kHz
#     Total eff: 96.75%, pure eff: 1.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(46.95729074260443), np.float64(58.82946811024219), np.float64(36.37727089327916)):
#     Total rate = 20.90 kHz, pure rate: 3.91 kHz
#     Total eff: 97.36%, pure eff: 1.80%
# L1_DoublePFJet8_Emyr_Mass(np.float64(24.831188528411275), np.float64(45.25496398689599), np.float64(54.356069658677384)):
#     Total rate = 208.84 kHz, pure rate: 111.75 kHz
#     Total eff: 99.04%, pure eff: 3.48%
# L1_DoublePFJet8_Emyr_Mass(np.float64(62.712937190928315), np.float64(81.43831702164094), np.float64(45.7522365459213)):
#     Total rate = 5.48 kHz, pure rate: 0.34 kHz
#     Total eff: 96.14%, pure eff: 0.57%L1_DoublePFJet8_Emyr_Mass(np.float64(33.21364283829762), np.float64(68.41113328792366), np.float64(58.72689307787412)):
#     Total rate = 76.07 kHz, pure rate: 26.87 kHz
#     Total eff: 98.51%, pure eff: 2.94%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.97073009408049), np.float64(109.7062202806086), np.float64(46.2877512423596)):
#     Total rate = 28.71 kHz, pure rate: 4.46 kHz
#     Total eff: 97.44%, pure eff: 1.87%
# L1_DoublePFJet8_Emyr_Mass(np.float64(15.865852350015288), np.float64(133.8033416574614), np.float64(113.97439314797609)):
#     Total rate = 24.94 kHz, pure rate: 0.27 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(57.447298745082115), np.float64(65.52376548585366), np.float64(61.118406348455636)):
#     Total rate = 8.34 kHz, pure rate: 0.63 kHz
#     Total eff: 96.41%, pure eff: 0.84%
# L1_DoublePFJet8_Emyr_Mass(np.float64(32.65307941520807), np.float64(82.25351030144009), np.float64(67.78476316311529)):
#     Total rate = 61.72 kHz, pure rate: 15.14 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.08772085538728), np.float64(58.32827843500262), np.float64(43.91377883231777)):
#     Total rate = 52.35 kHz, pure rate: 17.79 kHz
#     Total eff: 98.20%, pure eff: 2.64%L1_DoublePFJet8_Emyr_Mass(np.float64(20.065663262019815), np.float64(63.37061463289214), np.float64(32.47497737018013)):
#     Total rate = 545.07 kHz, pure rate: 388.17 kHz
#     Total eff: 99.39%, pure eff: 3.82%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(50.17803621867567), np.float64(70.4712090276065), np.float64(96.91044685367537)):
#     Total rate = 11.05 kHz, pure rate: 0.56 kHz
#     Total eff: 96.41%, pure eff: 0.84%
# L1_DoublePFJet8_Emyr_Mass(np.float64(60.02494700209908), np.float64(36.79918522936397), np.float64(41.078479617016704)):
#     Total rate = 6.83 kHz, pure rate: 0.45 kHz
#     Total eff: 96.33%, pure eff: 0.76%
# L1_DoublePFJet8_Emyr_Mass(np.float64(30.75986607554125), np.float64(95.60233181772618), np.float64(109.12256854184545)):
#     Total rate = 24.25 kHz, pure rate: 0.75 kHz
#     Total eff: 96.22%, pure eff: 0.65%
# L1_DoublePFJet8_Emyr_Mass(np.float64(57.52572052730633), np.float64(92.33020212096099), np.float64(39.00407357454553)):
#     Total rate = 8.36 kHz, pure rate: 0.63 kHz
#     Total eff: 96.44%, pure eff: 0.88%
# L1_DoublePFJet8_Emyr_Mass(np.float64(62.60206894844793), np.float64(60.74520766931533), np.float64(37.59109527307134)):
#     Total rate = 5.54 kHz, pure rate: 0.36 kHz
#     Total eff: 96.14%, pure eff: 0.57%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.18678535305383), np.float64(74.27237688568478), np.float64(134.45373293681374)):
#     Total rate = 10.58 kHz, pure rate: 0.03 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(29.991135737817608), np.float64(91.0951410178229), np.float64(87.96879408633812)):
#     Total rate = 45.32 kHz, pure rate: 4.57 kHz
#     Total eff: 97.29%, pure eff: 1.72%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.90937758167375), np.float64(92.36869581459788), np.float64(41.751719347091964)):
#     Total rate = 59.82 kHz, pure rate: 17.24 kHz
#     Total eff: 98.51%, pure eff: 2.94%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.798136441271495), np.float64(48.056102212328334), np.float64(70.39173963781994)):
#     Total rate = 55.41 kHz, pure rate: 13.21 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.198127639925396), np.float64(58.257050046465835), np.float64(43.618568807618914)):
#     Total rate = 65.99 kHz, pure rate: 25.25 kHz
#     Total eff: 98.32%, pure eff: 2.75%
# L1_DoublePFJet8_Emyr_Mass(np.float64(61.37722261457287), np.float64(41.89454811340825), np.float64(53.65168300385744)):
#     Total rate = 6.12 kHz, pure rate: 0.38 kHz
#     Total eff: 96.18%, pure eff: 0.61%
# L1_DoublePFJet8_Emyr_Mass(np.float64(13.554865693877815), np.float64(109.81534220349457), np.float64(28.651004770383715)):
#     Total rate = 134.28 kHz, pure rate: 35.63 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(49.53905637785415), np.float64(45.185156939931204), np.float64(112.51746906297325)):
#     Total rate = 9.35 kHz, pure rate: 0.20 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(58.25842207937194), np.float64(64.57681442694101), np.float64(78.21286738565945)):
#     Total rate = 7.42 kHz, pure rate: 0.49 kHz
#     Total eff: 96.41%, pure eff: 0.84%
# L1_DoublePFJet8_Emyr_Mass(np.float64(64.36603512116392), np.float64(92.07437867208975), np.float64(116.37363960877542)):
#     Total rate = 3.74 kHz, pure rate: 0.05 kHz
#     Total eff: 95.80%, pure eff: 0.23%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.49813842780707), np.float64(54.85549789927036), np.float64(36.370672177079044)):
#     Total rate = 332.35 kHz, pure rate: 223.87 kHz
#     Total eff: 99.12%, pure eff: 3.56%
# differential_evolution step 3: f(x)= -0.02255351681957185
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.94818203566213), np.float64(70.97880181917198), np.float64(53.19115275374122)):
#     Total rate = 43.57 kHz, pure rate: 12.51 kHz
#     Total eff: 98.01%, pure eff: 2.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(59.81701372596305), np.float64(101.28095358020529), np.float64(130.86647144204832)):
#     Total rate = 4.40 kHz, pure rate: 0.03 kHz
#     Total eff: 95.72%, pure eff: 0.15%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.21509978064233), np.float64(104.31746673107239), np.float64(56.0548474239818)):
#     Total rate = 48.08 kHz, pure rate: 8.77 kHz
#     Total eff: 98.05%, pure eff: 2.48%L1_DoublePFJet8_Emyr_Mass(np.float64(19.94562341157562), np.float64(53.1740394358198), np.float64(84.1144565139532)):
#     Total rate = 78.69 kHz, pure rate: 10.71 kHz
#     Total eff: 97.52%, pure eff: 1.95%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(56.48425842245284), np.float64(39.02052114198337), np.float64(139.34145746544218)):
#     Total rate = 4.65 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.87567584232196), np.float64(58.73742634846305), np.float64(63.10339184634801)):
#     Total rate = 58.88 kHz, pure rate: 17.50 kHz
#     Total eff: 98.28%, pure eff: 2.71%
# L1_DoublePFJet8_Emyr_Mass(np.float64(69.6045326643808), np.float64(81.07317944064906), np.float64(108.80418842584305)):
#     Total rate = 2.77 kHz, pure rate: 0.03 kHz
#     Total eff: 95.80%, pure eff: 0.23%L1_DoublePFJet8_Emyr_Mass(np.float64(20.016344733009422), np.float64(83.99856951212824), np.float64(110.05755460337707)):
#     Total rate = 30.94 kHz, pure rate: 0.88 kHz
#     Total eff: 96.10%, pure eff: 0.54%
# L1_DoublePFJet8_Emyr_Mass(np.float64(22.78597876555669), np.float64(95.70455462455138), np.float64(116.49300926373652)):
#     Total rate = 24.52 kHz, pure rate: 0.55 kHz
#     Total eff: 95.87%, pure eff: 0.31%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(17.02193045840254), np.float64(125.7955000941884), np.float64(27.98216039226528)):
#     Total rate = 73.91 kHz, pure rate: 8.70 kHz
#     Total eff: 97.21%, pure eff: 1.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.89564631180885), np.float64(41.7375098938971), np.float64(20.049282784472553)):
#     Total rate = 406.42 kHz, pure rate: 294.31 kHz
#     Total eff: 99.08%, pure eff: 3.52%L1_DoublePFJet8_Emyr_Mass(np.float64(3.5348947932332386), np.float64(64.23774188779834), np.float64(105.01014735526562)):
#     Total rate = 39.78 kHz, pure rate: 1.68 kHz
#     Total eff: 96.41%, pure eff: 0.84%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(51.00628034263863), np.float64(80.42241574666812), np.float64(64.93029564837374)):
#     Total rate = 13.04 kHz, pure rate: 1.41 kHz
#     Total eff: 96.90%, pure eff: 1.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(23.267260963209164), np.float64(76.22124359961802), np.float64(57.57063356646877)):
#     Total rate = 170.22 kHz, pure rate: 72.68 kHz
#     Total eff: 99.08%, pure eff: 3.52%L1_DoublePFJet8_Emyr_Mass(np.float64(27.741495342463914), np.float64(111.92518170779921), np.float64(116.48481873173665)):
#     Total rate = 22.33 kHz, pure rate: 0.50 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(42.388690278996435), np.float64(87.37852766383634), np.float64(58.40117042206468)):
#     Total rate = 28.29 kHz, pure rate: 5.35 kHz
#     Total eff: 97.82%, pure eff: 2.26%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(29.110692668809158), np.float64(31.023639343020747), np.float64(140.91351932197315)):
#     Total rate = 11.49 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%L1_DoublePFJet8_Emyr_Mass(np.float64(60.299823303310276), np.float64(41.72216665032673), np.float64(75.44631647925517)):
#     Total rate = 6.50 kHz, pure rate: 0.39 kHz
#     Total eff: 96.29%, pure eff: 0.73%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(62.24858269026153), np.float64(139.47333667427475), np.float64(35.886017449533675)):
#     Total rate = 5.20 kHz, pure rate: 0.14 kHz
#     Total eff: 95.87%, pure eff: 0.31%
# L1_DoublePFJet8_Emyr_Mass(np.float64(19.36397647517852), np.float64(82.01731085040049), np.float64(78.3026190307863)):
#     Total rate = 100.90 kHz, pure rate: 19.19 kHz
#     Total eff: 97.82%, pure eff: 2.26%
# L1_DoublePFJet8_Emyr_Mass(np.float64(23.950696063912645), np.float64(122.79626037821225), np.float64(25.67476451414683)):
#     Total rate = 67.62 kHz, pure rate: 9.53 kHz
#     Total eff: 97.40%, pure eff: 1.83%
# L1_DoublePFJet8_Emyr_Mass(np.float64(69.40687475636074), np.float64(44.30508548047525), np.float64(55.166523911535876)):
#     Total rate = 3.26 kHz, pure rate: 0.11 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.374362638997376), np.float64(68.82331904128529), np.float64(33.90085813346912)):
#     Total rate = 85.91 kHz, pure rate: 37.04 kHz
#     Total eff: 98.59%, pure eff: 3.02%
# L1_DoublePFJet8_Emyr_Mass(np.float64(51.46405521818255), np.float64(81.43831702164094), np.float64(48.7737133988225)):
#     Total rate = 13.18 kHz, pure rate: 1.55 kHz
#     Total eff: 97.13%, pure eff: 1.57%
# L1_DoublePFJet8_Emyr_Mass(np.float64(1.121172270362763), np.float64(32.95975164867339), np.float64(57.37130728452772)):
#     Total rate = 420.22 kHz, pure rate: 246.26 kHz
#     Total eff: 99.46%, pure eff: 3.90%
# L1_DoublePFJet8_Emyr_Mass(np.float64(54.07842004144064), np.float64(65.40051424326927), np.float64(90.2699035101065)):
#     Total rate = 9.41 kHz, pure rate: 0.63 kHz
#     Total eff: 96.44%, pure eff: 0.88%
# L1_DoublePFJet8_Emyr_Mass(np.float64(68.65212839464431), np.float64(92.33020212096099), np.float64(89.51276743967829)):
#     Total rate = 3.30 kHz, pure rate: 0.09 kHz
#     Total eff: 95.91%, pure eff: 0.34%L1_DoublePFJet8_Emyr_Mass(np.float64(26.470287535144312), np.float64(68.73432887374761), np.float64(65.04170794693512)):
#     Total rate = 119.46 kHz, pure rate: 43.29 kHz
#     Total eff: 98.59%, pure eff: 3.02%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(23.730767587792943), np.float64(100.53852740256852), np.float64(119.77246948295083)):
#     Total rate = 21.87 kHz, pure rate: 0.42 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(50.699737276680345), np.float64(101.75092601390119), np.float64(61.118406348455636)):
#     Total rate = 13.18 kHz, pure rate: 1.22 kHz
#     Total eff: 96.90%, pure eff: 1.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.95309574263198), np.float64(89.12219197761716), np.float64(63.495340007264545)):
#     Total rate = 39.80 kHz, pure rate: 8.60 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.87019070909621), np.float64(95.60233181772618), np.float64(56.29896263433163)):
#     Total rate = 56.96 kHz, pure rate: 13.67 kHz
#     Total eff: 98.32%, pure eff: 2.75%L1_DoublePFJet8_Emyr_Mass(np.float64(67.36767248567827), np.float64(87.93947098190289), np.float64(106.50771427073931)):
#     Total rate = 3.26 kHz, pure rate: 0.05 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(25.668209618506317), np.float64(50.5021505202653), np.float64(142.01571698365575)):
#     Total rate = 11.82 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(49.44798360201592), np.float64(32.81801582804264), np.float64(104.34971317630429)):
#     Total rate = 10.25 kHz, pure rate: 0.28 kHz
#     Total eff: 96.06%, pure eff: 0.50%
# L1_DoublePFJet8_Emyr_Mass(np.float64(32.47878816485725), np.float64(65.6374486006334), np.float64(24.80067421955529)):
#     Total rate = 116.81 kHz, pure rate: 57.68 kHz
#     Total eff: 98.70%, pure eff: 3.13%
# L1_DoublePFJet8_Emyr_Mass(np.float64(58.566574313351005), np.float64(158.1035091324418), np.float64(58.407989898393595)):
#     Total rate = 5.43 kHz, pure rate: 0.03 kHz
#     Total eff: 95.68%, pure eff: 0.11%
# L1_DoublePFJet8_Emyr_Mass(np.float64(18.865750237225715), np.float64(90.31757628357161), np.float64(36.462828532333106)):
#     Total rate = 212.60 kHz, pure rate: 92.00 kHz
#     Total eff: 99.16%, pure eff: 3.59%
# L1_DoublePFJet8_Emyr_Mass(np.float64(29.450464690855267), np.float64(69.09860573412094), np.float64(45.15586058595557)):
#     Total rate = 141.94 kHz, pure rate: 69.29 kHz
#     Total eff: 98.81%, pure eff: 3.25%
# L1_DoublePFJet8_Emyr_Mass(np.float64(68.32648314779408), np.float64(45.83807749692527), np.float64(77.46351358182244)):
#     Total rate = 3.49 kHz, pure rate: 0.11 kHz
#     Total eff: 95.91%, pure eff: 0.34%
# L1_DoublePFJet8_Emyr_Mass(np.float64(12.045151023384754), np.float64(57.13661905508687), np.float64(57.373053196870416)):
#     Total rate = 373.34 kHz, pure rate: 214.27 kHz
#     Total eff: 99.43%, pure eff: 3.86%
# L1_DoublePFJet8_Emyr_Mass(np.float64(31.693952409995934), np.float64(114.65926166880432), np.float64(142.54668231197115)):
#     Total rate = 10.33 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# L1_DoublePFJet8_Emyr_Mass(np.float64(58.25842207937194), np.float64(64.57681442694101), np.float64(84.71670703534511)):
#     Total rate = 7.33 kHz, pure rate: 0.45 kHz
#     Total eff: 96.33%, pure eff: 0.76%
# L1_DoublePFJet8_Emyr_Mass(np.float64(61.83226020281876), np.float64(45.167571825503444), np.float64(110.17514539320933)):
#     Total rate = 4.68 kHz, pure rate: 0.06 kHz
#     Total eff: 95.83%, pure eff: 0.27%
# L1_DoublePFJet8_Emyr_Mass(np.float64(13.406589243716223), np.float64(124.3807506732991), np.float64(139.47356022316833)):
#     Total rate = 13.98 kHz, pure rate: 0.02 kHz
#     Total eff: 95.64%, pure eff: 0.08%
# differential_evolution step 4: f(x)= -0.02484709480122327
# L1_DoublePFJet8_Emyr_Mass(np.float64(53.26527437393457), np.float64(104.31746673107239), np.float64(44.23998229597987)):
#     Total rate = 11.29 kHz, pure rate: 0.94 kHz
#     Total eff: 96.75%, pure eff: 1.19%
# L1_DoublePFJet8_Emyr_Mass(np.float64(21.07786176635438), np.float64(122.19429232697297), np.float64(84.574502954201)):
#     Total rate = 48.91 kHz, pure rate: 2.80 kHz
#     Total eff: 96.52%, pure eff: 0.96%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.858671026098406), np.float64(82.94700869414145), np.float64(80.50814730543759)):
#     Total rate = 43.41 kHz, pure rate: 6.31 kHz
#     Total eff: 97.44%, pure eff: 1.87%
# ...
#     Total rate = 50.70 kHz, pure rate: 10.44 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.48048038574606), np.float64(91.5058423142881), np.float64(56.46223754103382)):
#     Total rate = 47.19 kHz, pure rate: 11.32 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.334386202406534), np.float64(86.45379581280575), np.float64(56.96388136881719)):
#     Total rate = 38.03 kHz, pure rate: 8.88 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.7837957244292), np.float64(85.54019001026576), np.float64(57.801158952424686)):
#     Total rate = 39.72 kHz, pure rate: 9.39 kHz
#     Total eff: 98.01%, pure eff: 2.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.328312934866666), np.float64(91.731813519997), np.float64(58.471489860461595)):
#     Total rate = 51.27 kHz, pure rate: 12.32 kHz
#     Total eff: 98.39%, pure eff: 2.83%L1_DoublePFJet8_Emyr_Mass(np.float64(37.54674843351648), np.float64(92.01616358973646), np.float64(58.42692234674887)):
#     Total rate = 42.08 kHz, pure rate: 9.35 kHz
#     Total eff: 98.20%, pure eff: 2.64%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.78854476264957), np.float64(91.26333966565252), np.float64(57.56591896428995)):
#     Total rate = 45.37 kHz, pure rate: 10.58 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.54449396890649), np.float64(95.90491555178077), np.float64(54.96591933543601)):
#     Total rate = 45.59 kHz, pure rate: 10.30 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.47650771263923), np.float64(90.39335426491583), np.float64(57.072968690379675)):
#     Total rate = 47.33 kHz, pure rate: 11.46 kHz
#     Total eff: 98.24%, pure eff: 2.68%L1_DoublePFJet8_Emyr_Mass(np.float64(35.23792379107596), np.float64(95.29249287389759), np.float64(54.99181320155817)):
#     Total rate = 51.48 kHz, pure rate: 12.21 kHz
#     Total eff: 98.32%, pure eff: 2.75%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.786042343028186), np.float64(98.54518533341742), np.float64(59.70583861461361)):
#     Total rate = 48.89 kHz, pure rate: 10.00 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.13171436732363), np.float64(90.83012651779649), np.float64(55.54492363193473)):
#     Total rate = 49.25 kHz, pure rate: 12.15 kHz
#     Total eff: 98.28%, pure eff: 2.71%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.16465344754415), np.float64(87.1024765720619), np.float64(57.180965824487956)):
#     Total rate = 41.94 kHz, pure rate: 10.04 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.43051440191505), np.float64(93.04807760571157), np.float64(59.03554321228487)):
#     Total rate = 45.56 kHz, pure rate: 10.22 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.06779889260194), np.float64(86.10286121028426), np.float64(56.69244929210146)):
#     Total rate = 38.95 kHz, pure rate: 9.22 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.18792004306928), np.float64(92.90522472727996), np.float64(53.914462226655004)):
#     Total rate = 44.89 kHz, pure rate: 10.69 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.63003682317065), np.float64(87.8317471603499), np.float64(56.29049890599612)):
#     Total rate = 36.87 kHz, pure rate: 8.39 kHz
#     Total eff: 97.94%, pure eff: 2.37%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.168110376044886), np.float64(93.49159515262846), np.float64(55.35134942861828)):
#     Total rate = 48.25 kHz, pure rate: 11.43 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.92291262711372), np.float64(102.20827712670716), np.float64(58.623831275431996)):
#     Total rate = 50.23 kHz, pure rate: 9.64 kHz
#     Total eff: 98.13%, pure eff: 2.56%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.43039722293569), np.float64(90.89203026464004), np.float64(55.18645993597706)):
#     Total rate = 40.61 kHz, pure rate: 9.47 kHz
#     Total eff: 98.13%, pure eff: 2.56%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.24727328767605), np.float64(85.74425505546759), np.float64(55.589707562357304)):
#     Total rate = 38.81 kHz, pure rate: 9.27 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.80105589246316), np.float64(92.68908123935682), np.float64(57.07693612832984)):
#     Total rate = 45.11 kHz, pure rate: 10.40 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.56977948659118), np.float64(90.67463554360003), np.float64(53.52844965188699)):
#     Total rate = 58.38 kHz, pure rate: 15.66 kHz
#     Total eff: 98.51%, pure eff: 2.94%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.5123955826331), np.float64(94.89808058884296), np.float64(59.22549831244116)):
#     Total rate = 44.46 kHz, pure rate: 9.63 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.387264995867696), np.float64(88.21203738521689), np.float64(53.04622564627181)):
#     Total rate = 38.70 kHz, pure rate: 9.33 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# differential_evolution step 31: f(x)= -0.026376146788990806
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.404578175159536), np.float64(102.030692569196), np.float64(55.74324324819882)):
#     Total rate = 53.76 kHz, pure rate: 11.07 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.50599753768073), np.float64(92.30724693801382), np.float64(55.572579873073614)):
#     Total rate = 43.13 kHz, pure rate: 9.99 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(40.10084469246429), np.float64(84.24211239071131), np.float64(54.436485146031785)):
#     Total rate = 36.37 kHz, pure rate: 8.70 kHz
#     Total eff: 97.90%, pure eff: 2.33%L1_DoublePFJet8_Emyr_Mass(np.float64(37.635545523002776), np.float64(91.13414208134027), np.float64(55.59766886782302)):
#     Total rate = 42.88 kHz, pure rate: 10.00 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.43800059974659), np.float64(96.20356672640231), np.float64(56.64723152570081)):
#     Total rate = 41.33 kHz, pure rate: 8.75 kHz
#     Total eff: 98.09%, pure eff: 2.52%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.6981117148232), np.float64(100.10371228308091), np.float64(58.84222650878035)):
#     Total rate = 48.30 kHz, pure rate: 9.50 kHz
#     Total eff: 98.13%, pure eff: 2.56%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.37975007893922), np.float64(94.3099381467045), np.float64(59.56443053741236)):
#     Total rate = 44.92 kHz, pure rate: 9.71 kHz
#     Total eff: 98.17%, pure eff: 2.60%L1_DoublePFJet8_Emyr_Mass(np.float64(36.78514834837017), np.float64(89.98527715014801), np.float64(56.996558149526116)):
#     Total rate = 46.39 kHz, pure rate: 11.34 kHz
#     Total eff: 98.24%, pure eff: 2.68%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.871914753623564), np.float64(97.39444912848988), np.float64(55.926552274187785)):
#     Total rate = 47.03 kHz, pure rate: 10.36 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.178289813146776), np.float64(90.05835265162216), np.float64(56.95761305983453)):
#     Total rate = 44.71 kHz, pure rate: 10.65 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.2450744428642), np.float64(101.62062525521651), np.float64(58.13792598052381)):
#     Total rate = 49.38 kHz, pure rate: 9.57 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.31237241016344), np.float64(88.39733294162706), np.float64(57.88444694870348)):
#     Total rate = 40.91 kHz, pure rate: 9.52 kHz
#     Total eff: 98.13%, pure eff: 2.56%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.7943905165876), np.float64(90.94229313191131), np.float64(57.63482861737349)):
#     Total rate = 45.50 kHz, pure rate: 10.69 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.25520254029903), np.float64(97.82468303165135), np.float64(56.003421367865045)):
#     Total rate = 48.97 kHz, pure rate: 10.66 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.532465743605), np.float64(93.6467262596213), np.float64(59.04069897715412)):
#     Total rate = 44.87 kHz, pure rate: 9.88 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.271068015639194), np.float64(93.90944458544938), np.float64(58.44866665474496)):
#     Total rate = 42.19 kHz, pure rate: 9.14 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.07357212996972), np.float64(93.67251705025207), np.float64(57.070097838889474)):
#     Total rate = 43.52 kHz, pure rate: 9.60 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.78266894457505), np.float64(95.38922710998138), np.float64(54.497954444618486)):
#     Total rate = 41.38 kHz, pure rate: 9.14 kHz
#     Total eff: 98.13%, pure eff: 2.56%L1_DoublePFJet8_Emyr_Mass(np.float64(37.50169255232227), np.float64(93.92698927697786), np.float64(58.00432249437105)):
#     Total rate = 41.52 kHz, pure rate: 8.96 kHz
#     Total eff: 98.17%, pure eff: 2.60%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.76940390515223), np.float64(89.80412996997856), np.float64(56.84738973824232)):
#     Total rate = 46.51 kHz, pure rate: 11.35 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.91438421639908), np.float64(97.49355457123596), np.float64(59.42337367212214)):
#     Total rate = 49.21 kHz, pure rate: 10.38 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(38.97938782081105), np.float64(88.4668005717698), np.float64(54.06803950796517)):
#     Total rate = 39.47 kHz, pure rate: 9.44 kHz
#     Total eff: 98.01%, pure eff: 2.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.16939787931754), np.float64(86.35796780356665), np.float64(56.45524685420909)):
#     Total rate = 38.75 kHz, pure rate: 9.21 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.048460280439976), np.float64(97.51723958618656), np.float64(55.060089446972725)):
#     Total rate = 46.77 kHz, pure rate: 10.41 kHz
#     Total eff: 98.13%, pure eff: 2.56%L1_DoublePFJet8_Emyr_Mass(np.float64(39.49434410049508), np.float64(94.207589598803), np.float64(57.41564641033834)):
#     Total rate = 35.37 kHz, pure rate: 7.06 kHz
#     Total eff: 97.94%, pure eff: 2.37%
#
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.98136829707535), np.float64(91.23062839690303), np.float64(59.4463836928023)):
#     Total rate = 43.99 kHz, pure rate: 9.94 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.93604560566063), np.float64(97.42730816327118), np.float64(56.43308784958148)):
#     Total rate = 42.71 kHz, pure rate: 9.08 kHz
#     Total eff: 98.05%, pure eff: 2.48%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.92820401543037), np.float64(93.48153855058985), np.float64(57.10594299271854)):
#     Total rate = 44.17 kHz, pure rate: 9.88 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.46127618373093), np.float64(84.595559636503), np.float64(57.382071064053065)):
#     Total rate = 37.86 kHz, pure rate: 8.89 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.40074398324704), np.float64(90.20351317074629), np.float64(55.4754513583905)):
#     Total rate = 37.47 kHz, pure rate: 8.50 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.54449396890649), np.float64(103.53562165027377), np.float64(58.43603802661322)):
#     Total rate = 40.19 kHz, pure rate: 7.08 kHz
#     Total eff: 97.90%, pure eff: 2.33%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.86450255985593), np.float64(96.76068351077498), np.float64(57.46825932136631)):
#     Total rate = 39.42 kHz, pure rate: 8.00 kHz
#     Total eff: 98.01%, pure eff: 2.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.39658293687236), np.float64(93.82271387388884), np.float64(56.90782054941476)):
#     Total rate = 50.19 kHz, pure rate: 11.70 kHz
#     Total eff: 98.28%, pure eff: 2.71%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.12970708361063), np.float64(91.49387871729525), np.float64(58.8271745585052)):
#     Total rate = 43.68 kHz, pure rate: 9.89 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.69673233205509), np.float64(90.14523976374373), np.float64(58.36532514464132)):
#     Total rate = 46.15 kHz, pure rate: 10.99 kHz
#     Total eff: 98.24%, pure eff: 2.68%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.84029706770585), np.float64(96.86636994058398), np.float64(58.059643262129285)):
#     Total rate = 46.34 kHz, pure rate: 9.83 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(35.76544225985305), np.float64(95.11703078502362), np.float64(53.914462226655004)):
#     Total rate = 49.69 kHz, pure rate: 11.80 kHz
#     Total eff: 98.28%, pure eff: 2.71%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.02457412991856), np.float64(89.1860007365279), np.float64(52.996533556106215)):
#     Total rate = 39.66 kHz, pure rate: 9.61 kHz
#     Total eff: 98.01%, pure eff: 2.45%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.540584135905675), np.float64(99.90829530022577), np.float64(57.08997783734622)):
#     Total rate = 50.15 kHz, pure rate: 10.32 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.57338826005764), np.float64(93.56986802017157), np.float64(56.2555342452478)):
#     Total rate = 41.97 kHz, pure rate: 9.24 kHz
#     Total eff: 98.17%, pure eff: 2.60%
# L1_DoublePFJet8_Emyr_Mass(np.float64(33.94660693458189), np.float64(99.64855782206874), np.float64(57.18766743880654)):
#     Total rate = 52.75 kHz, pure rate: 11.13 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(39.35566000600916), np.float64(88.03843152002301), np.float64(55.91832662818267)):
#     Total rate = 37.84 kHz, pure rate: 8.74 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.868736777601654), np.float64(94.29074814640737), np.float64(53.04244229351859)):
#     Total rate = 45.62 kHz, pure rate: 10.80 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(37.523561031202824), np.float64(102.20827712670716), np.float64(58.271602461415334)):
#     Total rate = 37.89 kHz, pure rate: 6.78 kHz
#     Total eff: 97.97%, pure eff: 2.41%
# L1_DoublePFJet8_Emyr_Mass(np.float64(34.56977948659118), np.float64(94.53244996626664), np.float64(57.803423993340566)):
#     Total rate = 53.34 kHz, pure rate: 12.23 kHz
#     Total eff: 98.36%, pure eff: 2.79%
# differential_evolution step 32: f(x)= -0.026376146788990806
# Polishing solution with 'L-BFGS-B'
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.74648319120541), np.float64(93.83341587033289), np.float64(57.070097838889474)):
#     Total rate = 44.68 kHz, pure rate: 9.97 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.74648320120541), np.float64(93.83341587033289), np.float64(57.070097838889474)):
#     Total rate = 44.68 kHz, pure rate: 9.97 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.74648319120541), np.float64(93.83341588033288), np.float64(57.070097838889474)):
#     Total rate = 44.68 kHz, pure rate: 9.97 kHz
#     Total eff: 98.20%, pure eff: 2.64%
# L1_DoublePFJet8_Emyr_Mass(np.float64(36.74648319120541), np.float64(93.83341587033289), np.float64(57.070097848889475)):
#     Total rate = 44.68 kHz, pure rate: 9.97 kHz
#     Total eff: 98.20%, pure eff: 2.64%
#              message: Optimization terminated successfully.
#              success: True
#                  fun: -0.026376146788990806
#                    x: [ 3.675e+01  9.383e+01  5.707e+01]
#                  nit: 32
#                 nfev: 1489
#           population: [[ 3.675e+01  9.383e+01  5.707e+01]
#                        [ 3.751e+01  9.231e+01  5.557e+01]
#                        ...
#                        [ 3.677e+01  9.429e+01  5.683e+01]
#                        [ 3.651e+01  9.490e+01  5.923e+01]]
#  population_energies: [-2.638e-02 -2.638e-02 ... -2.638e-02 -2.599e-02]

# %%
# # L1_SinglePFJet8_Mass
# bounds = ((80, 130), (10, 40))
# L1_SinglePFJet8_Mass_Opti = de(objective, bounds=bounds, args=(L1_SinglePFJet8_Mass,), workers=-1, disp=True)
# L1_SinglePFJet8_Mass_Opti

# %%
# # L1_DoublePFJet8_dEtaMax
# bounds = ((50, 130), (40, 120))
# L1_DoublePFJet8_dEtaMax_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_dEtaMax,), workers=-1, disp=True)
# L1_DoublePFJet8_dEtaMax_Opti

# %%
# # L1_DoublePFJet8_dEtaMax_Mass
# bounds = ((50, 130), (0, 30), (40, 120), (0, 30) )
# L1_DoublePFJet8_dEtaMax_Mass_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_dEtaMax_Mass,), workers=-1, disp=True)
# L1_DoublePFJet8_dEtaMax_Mass_Opti

# %%
# # L1_DoublePFJet8_Sum_Mass
# bounds = ((0, 205), (0, 60) )
# L1_DoublePFJet8_Sum_Mass_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_Sum_Mass,), workers=-1, disp=True)
# L1_DoublePFJet8_Sum_Mass_Opti

# %%
# # L1_DoublePFJet8_Sum_EtaMax_Mass
# bounds = ((0, 205), (0, 60) )
# L1_DoublePFJet8_Sum_EtaMax_Mass_Opti = de(objective, bounds=bounds, args=(L1_DoublePFJet8_Sum_EtaMax_Mass,), workers=-1, disp=True)
# L1_DoublePFJet8_Sum_EtaMax_Mass_Opti

# %%
# # L1_SinglePFJet8_SinglePFJet4
# bounds = ((0, 130), (0, 130) )
# L1_SinglePFJet8_SinglePFJet4_Opti = de(objective, bounds=bounds, args=(L1_SinglePFJet8_SinglePFJet4,), workers=-1, disp=True)
# L1_SinglePFJet8_SinglePFJet4_Opti

# %%
# # L1_SinglePFJet8_SinglePFJet4_Mass
# bounds = ((0, 130), (0, 30), (0, 130) )
# L1_SinglePFJet8_SinglePFJet4_Mass_Opti = de(objective, bounds=bounds, args=(L1_SinglePFJet8_SinglePFJet4_Mass,), workers=-1, disp=True)
# L1_SinglePFJet8_SinglePFJet4_Mass_Opti

# %%
# # L1_SinglePFJet8_DoublePFJet4
# bounds = ((0, 130), (0, 130), (0, 130) )
# L1_SinglePFJet8_DoublePFJet4_Opti = de(objective, bounds=bounds, args=(L1_SinglePFJet8_DoublePFJet4,), workers=-1, disp=True)
# L1_SinglePFJet8_DoublePFJet4_Opti

# %%
# # L1_SinglePFJet8_DoublePFJet4_Mass
# bounds = ((0, 130), (0, 30), (0, 130), (0, 130) )
# L1_SinglePFJet8_DoublePFJet4_Mass_Opti = de(objective, bounds=bounds, args=(L1_SinglePFJet8_DoublePFJet4_Mass,), workers=-1, disp=True)
# L1_SinglePFJet8_DoublePFJet4_Mass_Opti

# %% [markdown]
# # 6. Investigate trigger performance

# %% [markdown]
# ### 6.1 Turnon curves

# %%
def get_turnon(mask, sc8):
    bins = np.linspace(0, 300, 31)
    xs = 0.5 * (bins[1:] + bins[:-1])
    effs, errs, counts = [], [], []
    for b in range(len(bins)-1):
        inBinMask = (sc8[f"genmass"] >= bins[b]) & (sc8[f"genmass"] < bins[b+1])
        denominator = ak.sum( inBinMask )
        numerator = ak.sum( mask & inBinMask )

        eff = numerator / denominator if denominator > 0 else 0
        err = np.sqrt(eff * (1-eff) / denominator) if denominator > 0 else 0

        effs.append(eff)
        errs.append(err)
        counts.append(denominator)

    return xs, np.array(effs), np.array(errs), np.array(counts)

# %%
def plot_turnon(xs, formatting, counts, **effs):
    plt.figure(figsize=(SCALE,2*SCALE/3))
    plt.bar(x=xs, height = counts/max(counts), width=xs[1]-xs[0], color="lightgrey", alpha=0.5, align="center")
    for label, (eff, err) in effs.items():
        plt.errorbar(xs, eff, xerr=xs[0], yerr=err,
                     capsize=5, fmt="-o", label=formatting[label])

    plt.legend()
    plt.grid()
    plt.show()

# %%
# formatting = {
#     "Full_menu": "Full menu",
#     "Full_and_L1_DoublePFJet8_dEtaMax_Mass": "L1_DoublePFJet8_dEtaMax_Mass"
#     }

# # full_menu_mask = sig_decisions.any(axis=1).values
# # xs, effs_baseline, errs_baseline, counts = get_turnon(full_menu_mask, sig_sc8)

# mask = L1_DoublePFJet8_dEtaMax_Mass(sig_sc8, None, 71.95889629199519, 15.595871084158233, 60.04119874222349, 12.905588652812998)
# xs, effs, errs, counts = get_turnon( mask, sig_sc8)

# plot_turnon(
#     xs, formatting=formatting, counts=counts,
#     # Full_menu=(effs_baseline, errs_baseline),
#     Full_and_L1_DoublePFJet8_dEtaMax_Mass=(effs, errs)
#     )
